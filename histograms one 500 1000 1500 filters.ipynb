# %%
import ROOT, math
from ROOT import TFile, TCanvas, TLegend, TLatex
# Out:
# Welcome to JupyROOT 6.30/02

# %%
file_all_500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/all__one_neutron_500MeV.root","read")
hist_hE_all_500MeV=file_all_500MeV.GetDirectory("HistMonitor").Get("hE")

file_all_1000MeV=TFile("~/test/data/simu_data/one_500_1000_1500/all__one_neutron_1000MeV.root","read")
hist_hE_all_1000MeV=file_all_1000MeV.GetDirectory("HistMonitor").Get("hE")

file_all_1500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/all__one_neutron_1500MeV.root","read")
hist_hE_all_1500MeV=file_all_1500MeV.GetDirectory("HistMonitor").Get("hE")

# %%
file_only_protons_500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/protons_only__one_neutron_500MeV.root","read")
hist_hE_only_protons_500MeV=file_only_protons_500MeV.GetDirectory("HistMonitor").Get("hE")

file_only_protons_1000MeV=TFile("~/test/data/simu_data/one_500_1000_1500/protons_only__one_neutron_1000MeV.root","read")
hist_hE_only_protons_1000MeV=file_only_protons_1000MeV.GetDirectory("HistMonitor").Get("hE")

file_only_protons_1500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/protons_only__one_neutron_1500MeV.root","read")
hist_hE_only_protons_1500MeV=file_only_protons_1500MeV.GetDirectory("HistMonitor").Get("hE")

# %%
file_all_500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/all__one_neutron_500MeV.root","read")
hist_hE_all_500MeV=file_all_500MeV.GetDirectory("HistMonitor").Get("hE")

file_all_1000MeV=TFile("~/test/data/simu_data/one_500_1000_1500/all__one_neutron_1000MeV.root","read")
hist_hE_all_1000MeV=file_all_1000MeV.GetDirectory("HistMonitor").Get("hE")

file_all_1500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/all__one_neutron_1500MeV.root","read")
hist_hE_all_1500MeV=file_all_1500MeV.GetDirectory("HistMonitor").Get("hE")

# %%
file_no_gamma_500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/no_gamma__one_neutron_500MeV.root","read")
hist_hE_no_gamma_500MeV=file_no_gamma_500MeV.GetDirectory("HistMonitor").Get("hE")

file_no_gamma_1000MeV=TFile("~/test/data/simu_data/one_500_1000_1500/no_gamma__one_neutron_1000MeV.root","read")
hist_hE_no_gamma_1000MeV=file_no_gamma_1000MeV.GetDirectory("HistMonitor").Get("hE")

file_no_gamma_1500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/no_gamma__one_neutron_1500MeV.root","read")
hist_hE_no_gamma_1500MeV=file_no_gamma_1500MeV.GetDirectory("HistMonitor").Get("hE")

# %%
file_no_electrons_positrons_500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/no_electrons_positrons__one_neutron_500MeV.root","read")
hist_hE_no_electrons_positrons_500MeV=file_no_electrons_positrons_500MeV.GetDirectory("HistMonitor").Get("hE")

file_no_electrons_positrons_1000MeV=TFile("~/test/data/simu_data/one_500_1000_1500/no_electrons_positrons__one_neutron_1000MeV.root","read")
hist_hE_no_electrons_positrons_1000MeV=file_no_electrons_positrons_1000MeV.GetDirectory("HistMonitor").Get("hE")

file_no_electrons_positrons_1500MeV=TFile("~/test/data/simu_data/one_500_1000_1500/no_electrons_positrons__one_neutron_1500MeV.root","read")
hist_hE_no_electrons_positrons_1500MeV=file_no_electrons_positrons_1500MeV.GetDirectory("HistMonitor").Get("hE")

# %%
#We want to scale the histograms so they all have a value of 1000 at the main peak of the data.

#set accordingly to cut out the first big peak in the data according to bin number
lower_peak_bin=42

#set the value the peaks should be normalised to
normalized_peak_height=1000

# %%
hist_hE_all_500MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_all_500MeV.GetNbinsX())
scaled_hist_hE_all_500MeV=normalized_peak_height/hist_hE_all_500MeV.GetBinContent(hist_hE_all_500MeV.GetMaximumBin())*hist_hE_all_500MeV

hist_hE_all_1000MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_all_1000MeV.GetNbinsX())
scaled_hist_hE_all_1000MeV=normalized_peak_height/hist_hE_all_1000MeV.GetBinContent(hist_hE_all_1000MeV.GetMaximumBin())*hist_hE_all_1000MeV

hist_hE_all_1500MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_all_1500MeV.GetNbinsX())
scaled_hist_hE_all_1500MeV=normalized_peak_height/hist_hE_all_1500MeV.GetBinContent(hist_hE_all_1500MeV.GetMaximumBin())*hist_hE_all_1500MeV

# %%
hist_hE_only_protons_500MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_only_protons_500MeV.GetNbinsX())
scaled_hist_hE_only_protons_500MeV=normalized_peak_height/hist_hE_only_protons_500MeV.GetBinContent(hist_hE_only_protons_500MeV.GetMaximumBin())*hist_hE_only_protons_500MeV

hist_hE_only_protons_1000MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_only_protons_1000MeV.GetNbinsX())
scaled_hist_hE_only_protons_1000MeV=normalized_peak_height/hist_hE_only_protons_1000MeV.GetBinContent(hist_hE_only_protons_1000MeV.GetMaximumBin())*hist_hE_only_protons_1000MeV

hist_hE_only_protons_1500MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_only_protons_1500MeV.GetNbinsX())
scaled_hist_hE_only_protons_1500MeV=normalized_peak_height/hist_hE_only_protons_1500MeV.GetBinContent(hist_hE_only_protons_1500MeV.GetMaximumBin())*hist_hE_only_protons_1500MeV

# %%
hist_hE_no_gamma_500MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_gamma_500MeV.GetNbinsX())
scaled_hist_hE_no_gamma_500MeV=normalized_peak_height/hist_hE_no_gamma_500MeV.GetBinContent(hist_hE_no_gamma_500MeV.GetMaximumBin())*hist_hE_no_gamma_500MeV

hist_hE_no_gamma_1000MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_gamma_1000MeV.GetNbinsX())
scaled_hist_hE_no_gamma_1000MeV=normalized_peak_height/hist_hE_no_gamma_1000MeV.GetBinContent(hist_hE_no_gamma_1000MeV.GetMaximumBin())*hist_hE_no_gamma_1000MeV

hist_hE_no_gamma_1500MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_gamma_1500MeV.GetNbinsX())
scaled_hist_hE_no_gamma_1500MeV=normalized_peak_height/hist_hE_no_gamma_1500MeV.GetBinContent(hist_hE_no_gamma_1500MeV.GetMaximumBin())*hist_hE_no_gamma_1500MeV

# %%
hist_hE_no_electrons_positrons_500MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_electrons_positrons_500MeV.GetNbinsX())
scaled_hist_hE_no_electrons_positrons_500MeV=normalized_peak_height/hist_hE_no_electrons_positrons_500MeV.GetBinContent(hist_hE_no_electrons_positrons_500MeV.GetMaximumBin())*hist_hE_no_electrons_positrons_500MeV

hist_hE_no_electrons_positrons_1000MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_electrons_positrons_1000MeV.GetNbinsX())
scaled_hist_hE_no_electrons_positrons_1000MeV=normalized_peak_height/hist_hE_no_electrons_positrons_1000MeV.GetBinContent(hist_hE_no_electrons_positrons_1000MeV.GetMaximumBin())*hist_hE_no_electrons_positrons_1000MeV

hist_hE_no_electrons_positrons_1500MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_electrons_positrons_1500MeV.GetNbinsX())
scaled_hist_hE_no_electrons_positrons_1500MeV=normalized_peak_height/hist_hE_no_electrons_positrons_1500MeV.GetBinContent(hist_hE_no_electrons_positrons_1500MeV.GetMaximumBin())*hist_hE_no_electrons_positrons_1500MeV

# %%
# %jsroot on
canvas=TCanvas("hE","Hit Energy",0,0,2000,2000)
canvas.Divide(2,2)

# %%
canvas.cd(1)

scaled_hist_hE_all_500MeV.SetTitle("all particles")
scaled_hist_hE_all_1000MeV.SetTitle("all particles")
scaled_hist_hE_all_1500MeV.SetTitle("all particles")

scaled_hist_hE_all_500MeV.SetLineColor(4)
scaled_hist_hE_all_1000MeV.SetLineColor(2)
scaled_hist_hE_all_1500MeV.SetLineColor(6)

scaled_hist_hE_all_500MeV.Draw("same hist")
scaled_hist_hE_all_1000MeV.Draw("same hist")
scaled_hist_hE_all_1500MeV.Draw("same hist")

scaled_hist_hE_all_500MeV.SetStats(0)
scaled_hist_hE_all_1000MeV.SetStats(0)
scaled_hist_hE_all_1500MeV.SetStats(0)

legend_all=TLegend(0.6,0.7,0.9,0.9)

legend_all.AddEntry(scaled_hist_hE_all_500MeV,"500 MeV")
legend_all.AddEntry(scaled_hist_hE_all_1000MeV,"1000 MeV")
legend_all.AddEntry(scaled_hist_hE_all_1500MeV,"1500 MeV")
legend_all.SetHeader("Hit Energies","C")
legend_all.Draw()


scaled_hist_hE_all_500MeV.GetXaxis().SetRange(0,scaled_hist_hE_all_500MeV.GetNbinsX())
scaled_hist_hE_all_1000MeV.GetXaxis().SetRange(0,scaled_hist_hE_all_1000MeV.GetNbinsX())
scaled_hist_hE_all_1500MeV.GetXaxis().SetRange(0,scaled_hist_hE_all_1500MeV.GetNbinsX())
hist_all_global_max_list=[scaled_hist_hE_all_500MeV.GetBinContent(scaled_hist_hE_all_500MeV.GetMaximumBin()),
                         scaled_hist_hE_all_1000MeV.GetBinContent(scaled_hist_hE_all_1000MeV.GetMaximumBin()),
                         scaled_hist_hE_all_1500MeV.GetBinContent(scaled_hist_hE_all_1500MeV.GetMaximumBin())]
scaled_hist_hE_all_500MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_all_global_max_list)/100)*100+100)
scaled_hist_hE_all_1000MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_all_global_max_list)/100)*100+100)
scaled_hist_hE_all_1500MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_all_global_max_list)/100)*100+100)

# %%
canvas.cd(2)

scaled_hist_hE_only_protons_500MeV.SetTitle("only protons")
scaled_hist_hE_only_protons_1000MeV.SetTitle("only protons")
scaled_hist_hE_only_protons_1500MeV.SetTitle("only protons")

scaled_hist_hE_only_protons_500MeV.SetLineColor(4)
scaled_hist_hE_only_protons_1000MeV.SetLineColor(2)
scaled_hist_hE_only_protons_1500MeV.SetLineColor(6)

scaled_hist_hE_only_protons_500MeV.Draw("same hist")
scaled_hist_hE_only_protons_1000MeV.Draw("same hist")
scaled_hist_hE_only_protons_1500MeV.Draw("same hist")

scaled_hist_hE_only_protons_500MeV.SetStats(0)
scaled_hist_hE_only_protons_1000MeV.SetStats(0)
scaled_hist_hE_only_protons_1500MeV.SetStats(0)

legend_only_protons=TLegend(0.6,0.7,0.9,0.9)

legend_only_protons.AddEntry(scaled_hist_hE_only_protons_500MeV,"500 MeV")
legend_only_protons.AddEntry(scaled_hist_hE_only_protons_1000MeV,"1000 MeV")
legend_only_protons.AddEntry(scaled_hist_hE_only_protons_1500MeV,"1500 MeV")
legend_only_protons.SetHeader("Hit Energies","C")
legend_only_protons.Draw()


scaled_hist_hE_only_protons_500MeV.GetXaxis().SetRange(0,scaled_hist_hE_only_protons_500MeV.GetNbinsX())
scaled_hist_hE_only_protons_1000MeV.GetXaxis().SetRange(0,scaled_hist_hE_only_protons_1000MeV.GetNbinsX())
scaled_hist_hE_only_protons_1500MeV.GetXaxis().SetRange(0,scaled_hist_hE_only_protons_1500MeV.GetNbinsX())
hist_only_protons_global_max_list=[scaled_hist_hE_only_protons_500MeV.GetBinContent(scaled_hist_hE_only_protons_500MeV.GetMaximumBin()),
                         scaled_hist_hE_only_protons_1000MeV.GetBinContent(scaled_hist_hE_only_protons_1000MeV.GetMaximumBin()),
                         scaled_hist_hE_only_protons_1500MeV.GetBinContent(scaled_hist_hE_only_protons_1500MeV.GetMaximumBin())]
scaled_hist_hE_only_protons_500MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_only_protons_global_max_list)/100)*100+100)
scaled_hist_hE_only_protons_1000MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_only_protons_global_max_list)/100)*100+100)
scaled_hist_hE_only_protons_1500MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_only_protons_global_max_list)/100)*100+100)

# %%
canvas.cd(3)

scaled_hist_hE_no_gamma_500MeV.SetTitle("no gamma")
scaled_hist_hE_no_gamma_1000MeV.SetTitle("no gamma")
scaled_hist_hE_no_gamma_1500MeV.SetTitle("no gamma")

scaled_hist_hE_no_gamma_500MeV.SetLineColor(4)
scaled_hist_hE_no_gamma_1000MeV.SetLineColor(2)
scaled_hist_hE_no_gamma_1500MeV.SetLineColor(6)

scaled_hist_hE_no_gamma_500MeV.Draw("same hist")
scaled_hist_hE_no_gamma_1000MeV.Draw("same hist")
scaled_hist_hE_no_gamma_1500MeV.Draw("same hist")

scaled_hist_hE_no_gamma_500MeV.SetStats(0)
scaled_hist_hE_no_gamma_1000MeV.SetStats(0)
scaled_hist_hE_no_gamma_1500MeV.SetStats(0)

legend_no_gamma=TLegend(0.6,0.7,0.9,0.9)
legend_no_gamma.SetHeader("Hit Energies","C")
legend_no_gamma.AddEntry(scaled_hist_hE_no_gamma_500MeV,"500 MeV")
legend_no_gamma.AddEntry(scaled_hist_hE_no_gamma_1000MeV,"1000 MeV")
legend_no_gamma.AddEntry(scaled_hist_hE_no_gamma_1500MeV,"1500 MeV")

legend_no_gamma.Draw()


scaled_hist_hE_no_gamma_500MeV.GetXaxis().SetRange(0,scaled_hist_hE_no_gamma_500MeV.GetNbinsX())
scaled_hist_hE_no_gamma_1000MeV.GetXaxis().SetRange(0,scaled_hist_hE_no_gamma_1000MeV.GetNbinsX())
scaled_hist_hE_no_gamma_1500MeV.GetXaxis().SetRange(0,scaled_hist_hE_no_gamma_1500MeV.GetNbinsX())
hist_no_gamma_global_max_list=[scaled_hist_hE_no_gamma_500MeV.GetBinContent(scaled_hist_hE_no_gamma_500MeV.GetMaximumBin()),
                         scaled_hist_hE_no_gamma_1000MeV.GetBinContent(scaled_hist_hE_no_gamma_1000MeV.GetMaximumBin()),
                         scaled_hist_hE_no_gamma_1500MeV.GetBinContent(scaled_hist_hE_no_gamma_1500MeV.GetMaximumBin())]
scaled_hist_hE_no_gamma_500MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_gamma_global_max_list)/100)*100+100)
scaled_hist_hE_no_gamma_1000MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_gamma_global_max_list)/100)*100+100)
scaled_hist_hE_no_gamma_1500MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_gamma_global_max_list)/100)*100+100)

# %%
canvas.cd(4)

scaled_hist_hE_no_electrons_positrons_500MeV.SetTitle("no e^{+}, e^{-}")
scaled_hist_hE_no_electrons_positrons_1000MeV.SetTitle("no e^{+}, e^{-}")
scaled_hist_hE_no_electrons_positrons_1500MeV.SetTitle("no e^{+}, e^{-}")

scaled_hist_hE_no_electrons_positrons_500MeV.SetLineColor(4)
scaled_hist_hE_no_electrons_positrons_1000MeV.SetLineColor(2)
scaled_hist_hE_no_electrons_positrons_1500MeV.SetLineColor(6)

scaled_hist_hE_no_electrons_positrons_500MeV.Draw("same hist")
scaled_hist_hE_no_electrons_positrons_1000MeV.Draw("same hist")
scaled_hist_hE_no_electrons_positrons_1500MeV.Draw("same hist")

scaled_hist_hE_no_electrons_positrons_500MeV.SetStats(0)
scaled_hist_hE_no_electrons_positrons_1000MeV.SetStats(0)
scaled_hist_hE_no_electrons_positrons_1500MeV.SetStats(0)

legend_no_electrons_positrons=TLegend(0.6,0.7,0.9,0.9)
legend_no_electrons_positrons.SetHeader("Hit Energies","C")
legend_no_electrons_positrons.AddEntry(scaled_hist_hE_no_electrons_positrons_500MeV,"500 MeV")
legend_no_electrons_positrons.AddEntry(scaled_hist_hE_no_electrons_positrons_1000MeV,"1000 MeV")
legend_no_electrons_positrons.AddEntry(scaled_hist_hE_no_electrons_positrons_1500MeV,"1500 MeV")

legend_no_electrons_positrons.Draw()


scaled_hist_hE_no_electrons_positrons_500MeV.GetXaxis().SetRange(0,scaled_hist_hE_no_electrons_positrons_500MeV.GetNbinsX())
scaled_hist_hE_no_electrons_positrons_1000MeV.GetXaxis().SetRange(0,scaled_hist_hE_no_electrons_positrons_1000MeV.GetNbinsX())
scaled_hist_hE_no_electrons_positrons_1500MeV.GetXaxis().SetRange(0,scaled_hist_hE_no_electrons_positrons_1500MeV.GetNbinsX())
hist_no_electrons_positrons_global_max_list=[scaled_hist_hE_no_electrons_positrons_500MeV.GetBinContent(scaled_hist_hE_no_electrons_positrons_500MeV.GetMaximumBin()),
                         scaled_hist_hE_no_electrons_positrons_1000MeV.GetBinContent(scaled_hist_hE_no_electrons_positrons_1000MeV.GetMaximumBin()),
                         scaled_hist_hE_no_electrons_positrons_1500MeV.GetBinContent(scaled_hist_hE_no_electrons_positrons_1500MeV.GetMaximumBin())]
scaled_hist_hE_no_electrons_positrons_500MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_electrons_positrons_global_max_list)/100)*100+100)
scaled_hist_hE_no_electrons_positrons_1000MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_electrons_positrons_global_max_list)/100)*100+100)
scaled_hist_hE_no_electrons_positrons_1500MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_electrons_positrons_global_max_list)/100)*100+100)

# %%
canvas.Draw()
canvas.SaveAs("three energies.png")
# Out:
# Info in <TCanvas::Print>: png file three energies.png has been created
# <div id="root_plot_1713875789632" style="width: 2000px; height: 2000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1713875789632(Core) {
# ...

# %%
#y-value cut-off factor for fits
fit_selection_scale=0.9
fit_selection_value=normalized_peak_height*fit_selection_scale

# %%
scaled_hist_hE_all_500MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_all_500MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_all_500MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_500MeV.GetNbinsX())),
                         scaled_hist_hE_all_500MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_all_500MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_500MeV.GetNbinsX())))
scaled_hist_hE_all_1000MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_all_1000MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_all_1000MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_1000MeV.GetNbinsX())),
                        scaled_hist_hE_all_1000MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_all_1000MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_1000MeV.GetNbinsX())))
scaled_hist_hE_all_1500MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_all_1500MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_all_1500MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_1500MeV.GetNbinsX())),
                        scaled_hist_hE_all_1500MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_all_1500MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_1500MeV.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      6.89864
# NDf                       =           12
# Edm                       =   1.3839e-06
# NCalls                    =          152
# Constant                  =      964.973   +/-   12.9876
# Mean                      =      15.1524   +/-   0.164642
# Sigma                     =      3.94908   +/-   0.839925     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      3.29313
# NDf                       =            2
# Edm                       =  4.45935e-06
# NCalls                    =          271
# Constant                  =      995.212   +/-   25.0255
# Mean                      =      10.1363   +/-   0.248807
# Sigma                     =      2.82543   +/-   2.76988      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
scaled_hist_hE_only_protons_500MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_only_protons_500MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_only_protons_500MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_protons_500MeV.GetNbinsX())),
                         scaled_hist_hE_only_protons_500MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_only_protons_500MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_protons_500MeV.GetNbinsX())))
scaled_hist_hE_only_protons_1000MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_only_protons_1000MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_only_protons_1000MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_protons_1000MeV.GetNbinsX())),
                        scaled_hist_hE_only_protons_1000MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_only_protons_1000MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_protons_1000MeV.GetNbinsX())))
scaled_hist_hE_only_protons_1500MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_only_protons_1500MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_only_protons_1500MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_protons_1500MeV.GetNbinsX())),
                        scaled_hist_hE_only_protons_1500MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_only_protons_1500MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_protons_1500MeV.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      18.0457
# NDf                       =           10
# Edm                       =  7.88874e-07
# NCalls                    =          195
# Constant                  =      958.817   +/-   14.398
# Mean                      =      14.9492   +/-   0.621652
# Sigma                     =       5.4668   +/-   5.61695      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      22.0157
# NDf                       =            7
# Edm                       =   2.1711e-06
# NCalls                    =          207
# Constant                  =      943.173   +/-   11.6486
# Mean                      =      10.7971   +/-   0.499001
# Sigma                     =      5.76633   +/-   3.70436      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
scaled_hist_hE_no_gamma_500MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_no_gamma_500MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_no_gamma_500MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_gamma_500MeV.GetNbinsX())),
                         scaled_hist_hE_no_gamma_500MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_no_gamma_500MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_gamma_500MeV.GetNbinsX())))
scaled_hist_hE_no_gamma_1000MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_no_gamma_1000MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_no_gamma_1000MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_gamma_1000MeV.GetNbinsX())),
                        scaled_hist_hE_no_gamma_1000MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_no_gamma_1000MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_gamma_1000MeV.GetNbinsX())))
scaled_hist_hE_no_gamma_1500MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_no_gamma_1500MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_no_gamma_1500MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_gamma_1500MeV.GetNbinsX())),
                        scaled_hist_hE_no_gamma_1500MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_no_gamma_1500MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_gamma_1500MeV.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      11.7495
# NDf                       =           11
# Edm                       =  1.35868e-08
# NCalls                    =          129
# Constant                  =      975.612   +/-   13.6565
# Mean                      =      14.9805   +/-   0.135999
# Sigma                     =      3.41481   +/-   0.653099     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      3.20849
# NDf                       =            6
# Edm                       =  1.53915e-07
# NCalls                    =          129
# Constant                  =      989.076   +/-   9.72504
# Mean                      =      10.6082   +/-   0.0593098
# Sigma                     =      2.06414   +/-   0.2527       	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
scaled_hist_hE_no_electrons_positrons_500MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_no_electrons_positrons_500MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_no_electrons_positrons_500MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_electrons_positrons_500MeV.GetNbinsX())),
                         scaled_hist_hE_no_electrons_positrons_500MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_no_electrons_positrons_500MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_electrons_positrons_500MeV.GetNbinsX())))
scaled_hist_hE_no_electrons_positrons_1000MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_no_electrons_positrons_1000MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_no_electrons_positrons_1000MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_electrons_positrons_1000MeV.GetNbinsX())),
                        scaled_hist_hE_no_electrons_positrons_1000MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_no_electrons_positrons_1000MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_electrons_positrons_1000MeV.GetNbinsX())))
scaled_hist_hE_no_electrons_positrons_1500MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_no_electrons_positrons_1500MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_no_electrons_positrons_1500MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_electrons_positrons_1500MeV.GetNbinsX())),
                        scaled_hist_hE_no_electrons_positrons_1500MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_no_electrons_positrons_1500MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_electrons_positrons_1500MeV.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      6.89864
# NDf                       =           12
# Edm                       =  1.38548e-06
# NCalls                    =          150
# Constant                  =      964.973   +/-   12.9876
# Mean                      =      15.1524   +/-   0.164642
# Sigma                     =      3.94908   +/-   0.839925     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      3.29313
# NDf                       =            2
# Edm                       =  4.45908e-06
# NCalls                    =          271
# Constant                  =      995.212   +/-   25.0255
# Mean                      =      10.1363   +/-   0.248807
# Sigma                     =      2.82543   +/-   2.76988      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
peak_position_hE_all_500MeV=scaled_hist_hE_all_500MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_all_1000MeV=scaled_hist_hE_all_1000MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_all_1500MeV=scaled_hist_hE_all_1500MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_all=[peak_position_hE_all_500MeV,
                         peak_position_hE_all_1000MeV,
                         peak_position_hE_all_1500MeV]
array_peak_positions_all
# Out:
# [15.152387622568865, 10.136328495981923, 10.064373790819332]

# %%
peak_position_hE_only_protons_500MeV=scaled_hist_hE_only_protons_500MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_only_protons_1000MeV=scaled_hist_hE_only_protons_1000MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_only_protons_1500MeV=scaled_hist_hE_only_protons_1500MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_only_protons=[peak_position_hE_only_protons_500MeV,
                         peak_position_hE_only_protons_1000MeV,
                         peak_position_hE_only_protons_1500MeV]
array_peak_positions_only_protons
# Out:
# [14.949235548926396, 10.797130703843937, 9.05235785080899]

# %%
peak_position_hE_no_gamma_500MeV=scaled_hist_hE_no_gamma_500MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_no_gamma_1000MeV=scaled_hist_hE_no_gamma_1000MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_no_gamma_1500MeV=scaled_hist_hE_no_gamma_1500MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_no_gamma=[peak_position_hE_no_gamma_500MeV,
                         peak_position_hE_no_gamma_1000MeV,
                         peak_position_hE_no_gamma_1500MeV]
array_peak_positions_no_gamma
# Out:
# [14.980472874823372, 10.608180764916819, 9.87454146117201]

# %%
peak_position_hE_no_electrons_positrons_500MeV=scaled_hist_hE_no_electrons_positrons_500MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_no_electrons_positrons_1000MeV=scaled_hist_hE_no_electrons_positrons_1000MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_no_electrons_positrons_1500MeV=scaled_hist_hE_no_electrons_positrons_1500MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_dd=[peak_position_hE_no_electrons_positrons_500MeV,
                         peak_position_hE_no_electrons_positrons_1000MeV,
                         peak_position_hE_no_electrons_positrons_1500MeV]
array_peak_positions_dd
# Out:
# [15.15238772553352, 10.136328497926392, 10.064373790814452]

# %%
template_root_file=TFile("template.root","RECREATE")

template_root_file.WriteObject(scaled_hist_hE_all_500MeV,"all_500MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_all_1000MeV,"all_1000MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_all_1500MeV,"all_1500MeV_HitEnergy_Hist")

template_root_file.WriteObject(scaled_hist_hE_only_protons_500MeV,"only_protons_500MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_only_protons_1000MeV,"only_protons_1000MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_only_protons_1500MeV,"only_protons_1500MeV_HitEnergy_Hist")

template_root_file.WriteObject(scaled_hist_hE_no_gamma_500MeV,"no_gamma_500MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_no_gamma_1000MeV,"no_gamma_1000MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_no_gamma_1500MeV,"no_gamma_1500MeV_HitEnergy_Hist")

template_root_file.WriteObject(scaled_hist_hE_no_electrons_positrons_500MeV,"no_electrons_positrons_500MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_no_electrons_positrons_1000MeV,"no_electrons_positrons_1000MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_no_electrons_positrons_1500MeV,"no_electrons_positrons_1500MeV_HitEnergy_Hist")

template_root_file.Close()
