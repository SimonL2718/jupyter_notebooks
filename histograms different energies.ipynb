# %%
import ROOT, math
from ROOT import TFile, TCanvas, TLegend, TLatex
# Out:
# Welcome to JupyROOT 6.30/02

# %%
file_500_all=TFile("~/test/data/simu_data/diff_e/500_all.root","read")
hist_hE_500_all=file_500_all.GetDirectory("HistMonitor").Get("hE")

file_500_protons=TFile("~/test/data/simu_data/diff_e/500_protons.root","read")
hist_hE_500_protons=file_500_protons.GetDirectory("HistMonitor").Get("hE")

file_500_no_electrons_positrons_gamma=TFile("~/test/data/simu_data/diff_e/500_no_electrons_positrons_gamma.root","read")
hist_hE_500_no_electrons_positrons_gamma=file_500_no_electrons_positrons_gamma.GetDirectory("HistMonitor").Get("hE")
# Out:
# Warning in <TClass::Init>: no dictionary for class FairFileHeader is available
# Warning in <TClass::Init>: no dictionary for class FairEventHeader is available
# Warning in <TClass::Init>: no dictionary for class R3BNeulandHit is available

# %%
file_700_all=TFile("~/test/data/simu_data/diff_e/700_all.root","read")
hist_hE_700_all=file_700_all.GetDirectory("HistMonitor").Get("hE")

file_700_protons=TFile("~/test/data/simu_data/diff_e/700_protons.root","read")
hist_hE_700_protons=file_700_protons.GetDirectory("HistMonitor").Get("hE")

file_700_no_electrons_positrons_gamma=TFile("~/test/data/simu_data/diff_e/700_no_electrons_positrons_gamma.root","read")
hist_hE_700_no_electrons_positrons_gamma=file_700_no_electrons_positrons_gamma.GetDirectory("HistMonitor").Get("hE")

# %%
file_500_all=TFile("~/test/data/simu_data/diff_e/500_all.root","read")
hist_hE_500_all=file_500_all.GetDirectory("HistMonitor").Get("hE")

file_500_protons=TFile("~/test/data/simu_data/diff_e/500_protons.root","read")
hist_hE_500_protons=file_500_protons.GetDirectory("HistMonitor").Get("hE")

file_500_no_electrons_positrons_gamma=TFile("~/test/data/simu_data/diff_e/500_no_electrons_positrons_gamma.root","read")
hist_hE_500_no_electrons_positrons_gamma=file_500_no_electrons_positrons_gamma.GetDirectory("HistMonitor").Get("hE")

# %%
file_1000_all=TFile("~/test/data/simu_data/diff_e/1000_all.root","read")
hist_hE_1000_all=file_1000_all.GetDirectory("HistMonitor").Get("hE")

file_1000_protons=TFile("~/test/data/simu_data/diff_e/1000_protons.root","read")
hist_hE_1000_protons=file_1000_protons.GetDirectory("HistMonitor").Get("hE")

file_1000_no_electrons_positrons_gamma=TFile("~/test/data/simu_data/diff_e/1000_no_electrons_positrons_gamma.root","read")
hist_hE_1000_no_electrons_positrons_gamma=file_1000_no_electrons_positrons_gamma.GetDirectory("HistMonitor").Get("hE")

# %%
file_1300_all=TFile("~/test/data/simu_data/diff_e/1300_all.root","read")
hist_hE_1300_all=file_1300_all.GetDirectory("HistMonitor").Get("hE")

file_1300_protons=TFile("~/test/data/simu_data/diff_e/1300_protons.root","read")
hist_hE_1300_protons=file_1300_protons.GetDirectory("HistMonitor").Get("hE")

file_1300_no_electrons_positrons_gamma=TFile("~/test/data/simu_data/diff_e/1300_no_electrons_positrons_gamma.root","read")
hist_hE_1300_no_electrons_positrons_gamma=file_1300_no_electrons_positrons_gamma.GetDirectory("HistMonitor").Get("hE")

# %%
#We want to scale the histograms so they all have a value of 1000 at the main peak of the data.

#set a1000ordingly to cut out the first big peak in the data a1000ording to bin number
lower_peak_bin=42

#set the value the peaks should be normalised to
normalized_peak_height=1000

# %%
hist_hE_500_all.GetXaxis().SetRange(lower_peak_bin,hist_hE_500_all.GetNbinsX())
scaled_hist_hE_500_all=normalized_peak_height/hist_hE_500_all.GetBinContent(hist_hE_500_all.GetMaximumBin())*hist_hE_500_all

hist_hE_500_protons.GetXaxis().SetRange(lower_peak_bin,hist_hE_500_protons.GetNbinsX())
scaled_hist_hE_500_protons=normalized_peak_height/hist_hE_500_protons.GetBinContent(hist_hE_500_protons.GetMaximumBin())*hist_hE_500_protons

hist_hE_500_no_electrons_positrons_gamma.GetXaxis().SetRange(lower_peak_bin,hist_hE_500_no_electrons_positrons_gamma.GetNbinsX())
scaled_hist_hE_500_no_electrons_positrons_gamma=normalized_peak_height/hist_hE_500_no_electrons_positrons_gamma.GetBinContent(hist_hE_500_no_electrons_positrons_gamma.GetMaximumBin())*hist_hE_500_no_electrons_positrons_gamma

# %%
hist_hE_700_all.GetXaxis().SetRange(lower_peak_bin,hist_hE_700_all.GetNbinsX())
scaled_hist_hE_700_all=normalized_peak_height/hist_hE_700_all.GetBinContent(hist_hE_700_all.GetMaximumBin())*hist_hE_700_all

hist_hE_700_protons.GetXaxis().SetRange(lower_peak_bin,hist_hE_700_protons.GetNbinsX())
scaled_hist_hE_700_protons=normalized_peak_height/hist_hE_700_protons.GetBinContent(hist_hE_700_protons.GetMaximumBin())*hist_hE_700_protons

hist_hE_700_no_electrons_positrons_gamma.GetXaxis().SetRange(lower_peak_bin,hist_hE_700_no_electrons_positrons_gamma.GetNbinsX())
scaled_hist_hE_700_no_electrons_positrons_gamma=normalized_peak_height/hist_hE_700_no_electrons_positrons_gamma.GetBinContent(hist_hE_700_no_electrons_positrons_gamma.GetMaximumBin())*hist_hE_700_no_electrons_positrons_gamma

# %%
hist_hE_1000_all.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000_all.GetNbinsX())
scaled_hist_hE_1000_all=normalized_peak_height/hist_hE_1000_all.GetBinContent(hist_hE_1000_all.GetMaximumBin())*hist_hE_1000_all

hist_hE_1000_protons.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000_protons.GetNbinsX())
scaled_hist_hE_1000_protons=normalized_peak_height/hist_hE_1000_protons.GetBinContent(hist_hE_1000_protons.GetMaximumBin())*hist_hE_1000_protons

hist_hE_1000_no_electrons_positrons_gamma.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000_no_electrons_positrons_gamma.GetNbinsX())
scaled_hist_hE_1000_no_electrons_positrons_gamma=normalized_peak_height/hist_hE_1000_no_electrons_positrons_gamma.GetBinContent(hist_hE_1000_no_electrons_positrons_gamma.GetMaximumBin())*hist_hE_1000_no_electrons_positrons_gamma

# %%
hist_hE_1300_all.GetXaxis().SetRange(lower_peak_bin,hist_hE_1300_all.GetNbinsX())
scaled_hist_hE_1300_all=normalized_peak_height/hist_hE_1300_all.GetBinContent(hist_hE_1300_all.GetMaximumBin())*hist_hE_1300_all

hist_hE_1300_protons.GetXaxis().SetRange(lower_peak_bin,hist_hE_1300_protons.GetNbinsX())
scaled_hist_hE_1300_protons=normalized_peak_height/hist_hE_1300_protons.GetBinContent(hist_hE_1300_protons.GetMaximumBin())*hist_hE_1300_protons

hist_hE_1300_no_electrons_positrons_gamma.GetXaxis().SetRange(lower_peak_bin,hist_hE_1300_no_electrons_positrons_gamma.GetNbinsX())
scaled_hist_hE_1300_no_electrons_positrons_gamma=normalized_peak_height/hist_hE_1300_no_electrons_positrons_gamma.GetBinContent(hist_hE_1300_no_electrons_positrons_gamma.GetMaximumBin())*hist_hE_1300_no_electrons_positrons_gamma

# %%
# %jsroot on
canvas=TCanvas("hE","Hit Energy",0,0,2000,2000)
canvas.Divide(2,2)

# %%
canvas.cd(1)

scaled_hist_hE_500_all.SetTitle("500MeV, n=1")
scaled_hist_hE_500_protons.SetTitle("500MeV, n=1")
scaled_hist_hE_500_no_electrons_positrons_gamma.SetTitle("500MeV, n=1")

scaled_hist_hE_500_all.SetLineColor(4)
scaled_hist_hE_500_protons.SetLineColor(2)
scaled_hist_hE_500_no_electrons_positrons_gamma.SetLineColor(6)

scaled_hist_hE_500_all.Draw("same hist")
scaled_hist_hE_500_protons.Draw("same hist")
scaled_hist_hE_500_no_electrons_positrons_gamma.Draw("same hist")

scaled_hist_hE_500_all.SetStats(0)
scaled_hist_hE_500_protons.SetStats(0)
scaled_hist_hE_500_no_electrons_positrons_gamma.SetStats(0)

legend_500=TLegend(0.6,0.7,0.9,0.9)

legend_500.AddEntry(scaled_hist_hE_500_all,"all particles")
legend_500.AddEntry(scaled_hist_hE_500_protons,"only protons")
legend_500.AddEntry(scaled_hist_hE_500_no_electrons_positrons_gamma,"no e^{+},e^{-},#gamma")
legend_500.SetHeader("Hit Energies","C")
legend_500.Draw()


scaled_hist_hE_500_all.GetXaxis().SetRange(0,scaled_hist_hE_500_all.GetNbinsX())
scaled_hist_hE_500_protons.GetXaxis().SetRange(0,scaled_hist_hE_500_protons.GetNbinsX())
scaled_hist_hE_500_no_electrons_positrons_gamma.GetXaxis().SetRange(0,scaled_hist_hE_500_no_electrons_positrons_gamma.GetNbinsX())
hist_500_global_max_list=[scaled_hist_hE_500_all.GetBinContent(scaled_hist_hE_500_all.GetMaximumBin()),
                         scaled_hist_hE_500_protons.GetBinContent(scaled_hist_hE_500_protons.GetMaximumBin()),
                         scaled_hist_hE_500_no_electrons_positrons_gamma.GetBinContent(scaled_hist_hE_500_no_electrons_positrons_gamma.GetMaximumBin())]
scaled_hist_hE_500_all.GetYaxis().SetRangeUser(0,math.floor(max(hist_500_global_max_list)/100)*100+100)
scaled_hist_hE_500_protons.GetYaxis().SetRangeUser(0,math.floor(max(hist_500_global_max_list)/100)*100+100)
scaled_hist_hE_500_no_electrons_positrons_gamma.GetYaxis().SetRangeUser(0,math.floor(max(hist_500_global_max_list)/100)*100+100)

# %%
canvas.cd(2)

scaled_hist_hE_700_all.SetTitle("700MeV, n=1")
scaled_hist_hE_700_protons.SetTitle("700MeV, n=1")
scaled_hist_hE_700_no_electrons_positrons_gamma.SetTitle("700MeV, n=1")

scaled_hist_hE_700_all.SetLineColor(4)
scaled_hist_hE_700_protons.SetLineColor(2)
scaled_hist_hE_700_no_electrons_positrons_gamma.SetLineColor(6)

scaled_hist_hE_700_all.Draw("same hist")
scaled_hist_hE_700_protons.Draw("same hist")
scaled_hist_hE_700_no_electrons_positrons_gamma.Draw("same hist")

scaled_hist_hE_700_all.SetStats(0)
scaled_hist_hE_700_protons.SetStats(0)
scaled_hist_hE_700_no_electrons_positrons_gamma.SetStats(0)

legend_700=TLegend(0.6,0.7,0.9,0.9)

legend_700.AddEntry(scaled_hist_hE_700_all,"all particles")
legend_700.AddEntry(scaled_hist_hE_700_protons,"only protons")
legend_700.AddEntry(scaled_hist_hE_700_no_electrons_positrons_gamma,"no e^{+},e^{-},#gamma")
legend_700.SetHeader("Hit Energies","C")
legend_700.Draw()


scaled_hist_hE_700_all.GetXaxis().SetRange(0,scaled_hist_hE_700_all.GetNbinsX())
scaled_hist_hE_700_protons.GetXaxis().SetRange(0,scaled_hist_hE_700_protons.GetNbinsX())
scaled_hist_hE_700_no_electrons_positrons_gamma.GetXaxis().SetRange(0,scaled_hist_hE_700_no_electrons_positrons_gamma.GetNbinsX())
hist_700_global_max_list=[scaled_hist_hE_700_all.GetBinContent(scaled_hist_hE_700_all.GetMaximumBin()),
                         scaled_hist_hE_700_protons.GetBinContent(scaled_hist_hE_700_protons.GetMaximumBin()),
                         scaled_hist_hE_700_no_electrons_positrons_gamma.GetBinContent(scaled_hist_hE_700_no_electrons_positrons_gamma.GetMaximumBin())]
scaled_hist_hE_700_all.GetYaxis().SetRangeUser(0,math.floor(max(hist_700_global_max_list)/100)*100+100)
scaled_hist_hE_700_protons.GetYaxis().SetRangeUser(0,math.floor(max(hist_700_global_max_list)/100)*100+100)
scaled_hist_hE_700_no_electrons_positrons_gamma.GetYaxis().SetRangeUser(0,math.floor(max(hist_700_global_max_list)/100)*100+100)

# %%
canvas.cd(3)

scaled_hist_hE_1000_all.SetTitle("1000MeV, n=1")
scaled_hist_hE_1000_protons.SetTitle("1000MeV, n=1")
scaled_hist_hE_1000_no_electrons_positrons_gamma.SetTitle("1000MeV, n=1")

scaled_hist_hE_1000_all.SetLineColor(4)
scaled_hist_hE_1000_protons.SetLineColor(2)
scaled_hist_hE_1000_no_electrons_positrons_gamma.SetLineColor(6)

scaled_hist_hE_1000_all.Draw("same hist")
scaled_hist_hE_1000_protons.Draw("same hist")
scaled_hist_hE_1000_no_electrons_positrons_gamma.Draw("same hist")

scaled_hist_hE_1000_all.SetStats(0)
scaled_hist_hE_1000_protons.SetStats(0)
scaled_hist_hE_1000_no_electrons_positrons_gamma.SetStats(0)

legend_1000=TLegend(0.6,0.7,0.9,0.9)
legend_1000.SetHeader("Hit Energies","C")
legend_1000.AddEntry(scaled_hist_hE_1000_all,"all particles")
legend_1000.AddEntry(scaled_hist_hE_1000_protons,"only protons")
legend_1000.AddEntry(scaled_hist_hE_1000_no_electrons_positrons_gamma,"no e^{+},e^{-},#gamma")

legend_1000.Draw()


scaled_hist_hE_1000_all.GetXaxis().SetRange(0,scaled_hist_hE_1000_all.GetNbinsX())
scaled_hist_hE_1000_protons.GetXaxis().SetRange(0,scaled_hist_hE_1000_protons.GetNbinsX())
scaled_hist_hE_1000_no_electrons_positrons_gamma.GetXaxis().SetRange(0,scaled_hist_hE_1000_no_electrons_positrons_gamma.GetNbinsX())
hist_1000_global_max_list=[scaled_hist_hE_1000_all.GetBinContent(scaled_hist_hE_1000_all.GetMaximumBin()),
                         scaled_hist_hE_1000_protons.GetBinContent(scaled_hist_hE_1000_protons.GetMaximumBin()),
                         scaled_hist_hE_1000_no_electrons_positrons_gamma.GetBinContent(scaled_hist_hE_1000_no_electrons_positrons_gamma.GetMaximumBin())]
scaled_hist_hE_1000_all.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000_global_max_list)/100)*100+100)
scaled_hist_hE_1000_protons.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000_global_max_list)/100)*100+100)
scaled_hist_hE_1000_no_electrons_positrons_gamma.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000_global_max_list)/100)*100+100)

# %%
canvas.cd(4)

scaled_hist_hE_1300_all.SetTitle("1300MeV, n=1")
scaled_hist_hE_1300_protons.SetTitle("1300MeV, n=1")
scaled_hist_hE_1300_no_electrons_positrons_gamma.SetTitle("1300MeV, n=1")

scaled_hist_hE_1300_all.SetLineColor(4)
scaled_hist_hE_1300_protons.SetLineColor(2)
scaled_hist_hE_1300_no_electrons_positrons_gamma.SetLineColor(6)

scaled_hist_hE_1300_all.Draw("same hist")
scaled_hist_hE_1300_protons.Draw("same hist")
scaled_hist_hE_1300_no_electrons_positrons_gamma.Draw("same hist")

scaled_hist_hE_1300_all.SetStats(0)
scaled_hist_hE_1300_protons.SetStats(0)
scaled_hist_hE_1300_no_electrons_positrons_gamma.SetStats(0)

legend_1300=TLegend(0.6,0.7,0.9,0.9)
legend_1300.SetHeader("Hit Energies","C")
legend_1300.AddEntry(scaled_hist_hE_1300_all,"all particles")
legend_1300.AddEntry(scaled_hist_hE_1300_protons,"only protons")
legend_1300.AddEntry(scaled_hist_hE_1300_no_electrons_positrons_gamma,"no e^{+},e^{-},#gamma")

legend_1300.Draw()


scaled_hist_hE_1300_all.GetXaxis().SetRange(0,scaled_hist_hE_1300_all.GetNbinsX())
scaled_hist_hE_1300_protons.GetXaxis().SetRange(0,scaled_hist_hE_1300_protons.GetNbinsX())
scaled_hist_hE_1300_no_electrons_positrons_gamma.GetXaxis().SetRange(0,scaled_hist_hE_1300_no_electrons_positrons_gamma.GetNbinsX())
hist_1300_global_max_list=[scaled_hist_hE_1300_all.GetBinContent(scaled_hist_hE_1300_all.GetMaximumBin()),
                         scaled_hist_hE_1300_protons.GetBinContent(scaled_hist_hE_1300_protons.GetMaximumBin()),
                         scaled_hist_hE_1300_no_electrons_positrons_gamma.GetBinContent(scaled_hist_hE_1300_no_electrons_positrons_gamma.GetMaximumBin())]
scaled_hist_hE_1300_all.GetYaxis().SetRangeUser(0,math.floor(max(hist_1300_global_max_list)/100)*100+100)
scaled_hist_hE_1300_protons.GetYaxis().SetRangeUser(0,math.floor(max(hist_1300_global_max_list)/100)*100+100)
scaled_hist_hE_1300_no_electrons_positrons_gamma.GetYaxis().SetRangeUser(0,math.floor(max(hist_1300_global_max_list)/100)*100+100)

# %%
canvas.Draw()
canvas.SaveAs("different_energies.png")
# Out:
# Info in <TCanvas::Print>: png file different_energies.png has been created
# <div id="root_plot_1713872891283" style="width: 2000px; height: 2000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1713872891283(Core) {
# ...

# %%
#y-value cut-off factor for fits
fit_selection_scale=0.9
fit_selection_value=normalized_peak_height*fit_selection_scale

# %%
scaled_hist_hE_500_all.Fit("gaus","S 0","same",
                         scaled_hist_hE_500_all.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_500_all.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500_all.GetNbinsX())),
                         scaled_hist_hE_500_all.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_500_all.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500_all.GetNbinsX())))
scaled_hist_hE_500_protons.Fit("gaus","S 0","same",
                        scaled_hist_hE_500_protons.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_500_protons.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500_protons.GetNbinsX())),
                        scaled_hist_hE_500_protons.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_500_protons.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500_protons.GetNbinsX())))
scaled_hist_hE_500_no_electrons_positrons_gamma.Fit("gaus","S 0","same",
                        scaled_hist_hE_500_no_electrons_positrons_gamma.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_500_no_electrons_positrons_gamma.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500_no_electrons_positrons_gamma.GetNbinsX())),
                        scaled_hist_hE_500_no_electrons_positrons_gamma.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_500_no_electrons_positrons_gamma.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500_no_electrons_positrons_gamma.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      10.6761
# NDf                       =           13
# Edm                       =  2.56458e-07
# NCalls                    =          149
# Constant                  =          945   +/-   15.0452
# Mean                      =      15.1014   +/-   0.188892
# Sigma                     =      3.97852   +/-   0.898466     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      8.75926
# NDf                       =            8
# Edm                       =  1.08315e-07
# NCalls                    =          185
# Constant                  =      923.868   +/-   18.8808
# Mean                      =      15.7592   +/-   0.912846
# Sigma                     =      6.34872   +/-   5.10331      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
scaled_hist_hE_700_all.Fit("gaus","S 0","same",
                         scaled_hist_hE_700_all.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_700_all.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_700_all.GetNbinsX())),
                         scaled_hist_hE_700_all.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_700_all.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_700_all.GetNbinsX())))
scaled_hist_hE_700_protons.Fit("gaus","S 0","same",
                        scaled_hist_hE_700_protons.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_700_protons.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_700_protons.GetNbinsX())),
                        scaled_hist_hE_700_protons.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_700_protons.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_700_protons.GetNbinsX())))
scaled_hist_hE_700_no_electrons_positrons_gamma.Fit("gaus","S 0","same",
                        scaled_hist_hE_700_no_electrons_positrons_gamma.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_700_no_electrons_positrons_gamma.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_700_no_electrons_positrons_gamma.GetNbinsX())),
                        scaled_hist_hE_700_no_electrons_positrons_gamma.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_700_no_electrons_positrons_gamma.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_700_no_electrons_positrons_gamma.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      9.50003
# NDf                       =           10
# Edm                       =  1.43302e-05
# NCalls                    =          166
# Constant                  =      958.601   +/-   12.7268
# Mean                      =      12.6648   +/-   0.247741
# Sigma                     =      4.55421   +/-   1.62619      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      10.2668
# NDf                       =            7
# Edm                       =   1.1497e-07
# NCalls                    =          166
# Constant                  =      935.737   +/-   17.0118
# Mean                      =      13.1641   +/-   0.5344
# Sigma                     =      4.99131   +/-   5.30471      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      7.70037
# ...

# %%
scaled_hist_hE_1000_all.Fit("gaus","S 0","same",
                         scaled_hist_hE_1000_all.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_1000_all.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000_all.GetNbinsX())),
                         scaled_hist_hE_1000_all.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_1000_all.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000_all.GetNbinsX())))
scaled_hist_hE_1000_protons.Fit("gaus","S 0","same",
                        scaled_hist_hE_1000_protons.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1000_protons.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000_protons.GetNbinsX())),
                        scaled_hist_hE_1000_protons.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1000_protons.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000_protons.GetNbinsX())))
scaled_hist_hE_1000_no_electrons_positrons_gamma.Fit("gaus","S 0","same",
                        scaled_hist_hE_1000_no_electrons_positrons_gamma.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1000_no_electrons_positrons_gamma.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000_no_electrons_positrons_gamma.GetNbinsX())),
                        scaled_hist_hE_1000_no_electrons_positrons_gamma.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1000_no_electrons_positrons_gamma.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000_no_electrons_positrons_gamma.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      5.25539
# NDf                       =            2
# Edm                       =   9.2734e-07
# NCalls                    =          281
# Constant                  =      987.919   +/-   27.0344
# Mean                      =      10.2128   +/-   0.299559
# Sigma                     =      2.82768   +/-   2.71335      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      17.4836
# NDf                       =            7
# Edm                       =  1.78346e-06
# NCalls                    =          275
# Constant                  =      949.621   +/-   25.0781
# Mean                      =      10.0646   +/-   0.610545
# Sigma                     =       5.7665   +/-   4.01315      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
scaled_hist_hE_1300_all.Fit("gaus","S 0","same",
                         scaled_hist_hE_1300_all.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_1300_all.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1300_all.GetNbinsX())),
                         scaled_hist_hE_1300_all.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_1300_all.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1300_all.GetNbinsX())))
scaled_hist_hE_1300_protons.Fit("gaus","S 0","same",
                        scaled_hist_hE_1300_protons.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1300_protons.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1300_protons.GetNbinsX())),
                        scaled_hist_hE_1300_protons.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1300_protons.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1300_protons.GetNbinsX())))
scaled_hist_hE_1300_no_electrons_positrons_gamma.Fit("gaus","S 0","same",
                        scaled_hist_hE_1300_no_electrons_positrons_gamma.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1300_no_electrons_positrons_gamma.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1300_no_electrons_positrons_gamma.GetNbinsX())),
                        scaled_hist_hE_1300_no_electrons_positrons_gamma.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1300_no_electrons_positrons_gamma.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1300_no_electrons_positrons_gamma.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      11.1563
# NDf                       =            6
# Edm                       =  1.89876e-06
# NCalls                    =          140
# Constant                  =      972.317   +/-   10.1575
# Mean                      =      10.2902   +/-   0.0693823
# Sigma                     =      2.25612   +/-   0.341422     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =        17.31
# NDf                       =           14
# Edm                       =  9.86789e-06
# NCalls                    =          157
# Constant                  =      956.313   +/-   9.34716
# Mean                      =       10.761   +/-   0.23019
# Sigma                     =      4.49379   +/-   0.755981     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
peak_position_hE_500_all=scaled_hist_hE_500_all.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_500_protons=scaled_hist_hE_500_protons.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_500_no_electrons_positrons_gamma=scaled_hist_hE_500_no_electrons_positrons_gamma.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_500=[peak_position_hE_500_all,
                         peak_position_hE_500_protons,
                         peak_position_hE_500_no_electrons_positrons_gamma]
array_peak_positions_500
# Out:
# [15.101353578029409, 15.75920729765127, 15.095834345587711]

# %%
peak_position_hE_700_all=scaled_hist_hE_700_all.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_700_protons=scaled_hist_hE_700_protons.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_700_no_electrons_positrons_gamma=scaled_hist_hE_700_no_electrons_positrons_gamma.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_700=[peak_position_hE_700_all,
                         peak_position_hE_700_protons,
                         peak_position_hE_700_no_electrons_positrons_gamma]
array_peak_positions_700
# Out:
# [12.664772356218053, 13.164068800412833, 12.915000343146856]

# %%
peak_position_hE_1000_all=scaled_hist_hE_1000_all.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1000_protons=scaled_hist_hE_1000_protons.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1000_no_electrons_positrons_gamma=scaled_hist_hE_1000_no_electrons_positrons_gamma.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_1000=[peak_position_hE_1000_all,
                         peak_position_hE_1000_protons,
                         peak_position_hE_1000_no_electrons_positrons_gamma]
array_peak_positions_1000
# Out:
# [10.212838466016851, 10.06463987190865, 11.06016621331734]

# %%
peak_position_hE_1300_all=scaled_hist_hE_1300_all.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1300_protons=scaled_hist_hE_1300_protons.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1300_no_electrons_positrons_gamma=scaled_hist_hE_1300_no_electrons_positrons_gamma.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_dd=[peak_position_hE_1300_all,
                         peak_position_hE_1300_protons,
                         peak_position_hE_1300_no_electrons_positrons_gamma]
array_peak_positions_dd
# Out:
# [10.290196346089463, 10.761042284602519, 10.420797654906181]

# %%
different_energies_root_file=TFile("different_energies.root","RECREATE")

different_energies_root_file.WriteObject(scaled_hist_hE_500_all,"500MeV all_HitEnergy_Hist")
different_energies_root_file.WriteObject(scaled_hist_hE_500_protons,"500MeV protons_HitEnergy_Hist")
different_energies_root_file.WriteObject(scaled_hist_hE_500_no_electrons_positrons_gamma,"500MeV no_electrons_positrons_gamma_HitEnergy_Hist")

different_energies_root_file.WriteObject(scaled_hist_hE_700_all,"700MeV all_HitEnergy_Hist")
different_energies_root_file.WriteObject(scaled_hist_hE_700_protons,"700MeV protons_HitEnergy_Hist")
different_energies_root_file.WriteObject(scaled_hist_hE_700_no_electrons_positrons_gamma,"700MeV no_electrons_positrons_gamma_HitEnergy_Hist")

different_energies_root_file.WriteObject(scaled_hist_hE_1000_all,"1000MeV all_HitEnergy_Hist")
different_energies_root_file.WriteObject(scaled_hist_hE_1000_protons,"1000MeV protons_HitEnergy_Hist")
different_energies_root_file.WriteObject(scaled_hist_hE_1000_no_electrons_positrons_gamma,"1000MeV no_electrons_positrons_gamma_HitEnergy_Hist")

different_energies_root_file.WriteObject(scaled_hist_hE_1300_all,"1300MeV all_HitEnergy_Hist")
different_energies_root_file.WriteObject(scaled_hist_hE_1300_protons,"1300MeV protons_HitEnergy_Hist")
different_energies_root_file.WriteObject(scaled_hist_hE_1300_no_electrons_positrons_gamma,"1300MeV no_electrons_positrons_gamma_HitEnergy_Hist")

different_energies_root_file.Close()
