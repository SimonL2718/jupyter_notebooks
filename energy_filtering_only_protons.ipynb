# %%
import ROOT, math
from ROOT import TFile, TCanvas, TLegend, TLatex

# %%
file_500MeV_above_0MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_0MeV_500MeV_n1.root","read")
hist_hE_500MeV_above_0MeV=file_500MeV_above_0MeV.GetDirectory("HistMonitor").Get("hE")

file_500MeV_above_10MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_10MeV_500MeV_n1.root","read")
hist_hE_500MeV_above_10MeV=file_500MeV_above_10MeV.GetDirectory("HistMonitor").Get("hE")

file_500MeV_above_20MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_20MeV_500MeV_n1.root","read")
hist_hE_500MeV_above_20MeV=file_500MeV_above_20MeV.GetDirectory("HistMonitor").Get("hE")

# %%
file_1000MeV_above_0MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_0MeV_1000MeV_n1.root","read")
hist_hE_1000MeV_above_0MeV=file_1000MeV_above_0MeV.GetDirectory("HistMonitor").Get("hE")

file_1000MeV_above_10MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_10MeV_1000MeV_n1.root","read")
hist_hE_1000MeV_above_10MeV=file_1000MeV_above_10MeV.GetDirectory("HistMonitor").Get("hE")

file_1000MeV_above_20MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_20MeV_1000MeV_n1.root","read")
hist_hE_1000MeV_above_20MeV=file_1000MeV_above_20MeV.GetDirectory("HistMonitor").Get("hE")

# %%
file_1500MeV_above_0MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_0MeV_1500MeV_n1.root","read")
hist_hE_1500MeV_above_0MeV=file_1500MeV_above_0MeV.GetDirectory("HistMonitor").Get("hE")

file_1500MeV_above_10MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_10MeV_1500MeV_n1.root","read")
hist_hE_1500MeV_above_10MeV=file_1500MeV_above_10MeV.GetDirectory("HistMonitor").Get("hE")

file_1500MeV_above_20MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_20MeV_1500MeV_n1.root","read")
hist_hE_1500MeV_above_20MeV=file_1500MeV_above_20MeV.GetDirectory("HistMonitor").Get("hE")

# %%
file_2000MeV_above_0MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_0MeV_2000MeV_n1.root","read")
hist_hE_2000MeV_above_0MeV=file_2000MeV_above_0MeV.GetDirectory("HistMonitor").Get("hE")

file_2000MeV_above_10MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_10MeV_2000MeV_n1.root","read")
hist_hE_2000MeV_above_10MeV=file_2000MeV_above_10MeV.GetDirectory("HistMonitor").Get("hE")

file_2000MeV_above_20MeV=TFile("~/test/data/simu_data/energy_filtering_all_only_protons_energies_500_1000_1500_2000_mult_1_events_100000/only_protons_above_20MeV_2000MeV_n1.root","read")
hist_hE_2000MeV_above_20MeV=file_2000MeV_above_20MeV.GetDirectory("HistMonitor").Get("hE")

# %%
#We want to scale the histograms so they all have a value of 1000 at the main peak of the data.

#set a1500MeVordingly to cut out the first big peak in the data a1500MeVording to bin number
lower_peak_bin=42

#set the value the peaks should be normalised to
normalized_peak_height=1000

# %%
hist_hE_500MeV_above_0MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_500MeV_above_0MeV.GetNbinsX())
scaled_hist_hE_500MeV_above_0MeV=normalized_peak_height/hist_hE_500MeV_above_0MeV.GetBinContent(hist_hE_500MeV_above_0MeV.GetMaximumBin())*hist_hE_500MeV_above_0MeV

hist_hE_500MeV_above_10MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_500MeV_above_10MeV.GetNbinsX())
scaled_hist_hE_500MeV_above_10MeV=normalized_peak_height/hist_hE_500MeV_above_10MeV.GetBinContent(hist_hE_500MeV_above_10MeV.GetMaximumBin())*hist_hE_500MeV_above_10MeV

hist_hE_500MeV_above_20MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_500MeV_above_20MeV.GetNbinsX())
scaled_hist_hE_500MeV_above_20MeV=normalized_peak_height/hist_hE_500MeV_above_20MeV.GetBinContent(hist_hE_500MeV_above_20MeV.GetMaximumBin())*hist_hE_500MeV_above_20MeV

# %%
hist_hE_1000MeV_above_0MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000MeV_above_0MeV.GetNbinsX())
scaled_hist_hE_1000MeV_above_0MeV=normalized_peak_height/hist_hE_1000MeV_above_0MeV.GetBinContent(hist_hE_1000MeV_above_0MeV.GetMaximumBin())*hist_hE_1000MeV_above_0MeV

hist_hE_1000MeV_above_10MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000MeV_above_10MeV.GetNbinsX())
scaled_hist_hE_1000MeV_above_10MeV=normalized_peak_height/hist_hE_1000MeV_above_10MeV.GetBinContent(hist_hE_1000MeV_above_10MeV.GetMaximumBin())*hist_hE_1000MeV_above_10MeV

hist_hE_1000MeV_above_20MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000MeV_above_20MeV.GetNbinsX())
scaled_hist_hE_1000MeV_above_20MeV=normalized_peak_height/hist_hE_1000MeV_above_20MeV.GetBinContent(hist_hE_1000MeV_above_20MeV.GetMaximumBin())*hist_hE_1000MeV_above_20MeV

# %%
hist_hE_1500MeV_above_0MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1500MeV_above_0MeV.GetNbinsX())
scaled_hist_hE_1500MeV_above_0MeV=normalized_peak_height/hist_hE_1500MeV_above_0MeV.GetBinContent(hist_hE_1500MeV_above_0MeV.GetMaximumBin())*hist_hE_1500MeV_above_0MeV

hist_hE_1500MeV_above_10MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1500MeV_above_10MeV.GetNbinsX())
scaled_hist_hE_1500MeV_above_10MeV=normalized_peak_height/hist_hE_1500MeV_above_10MeV.GetBinContent(hist_hE_1500MeV_above_10MeV.GetMaximumBin())*hist_hE_1500MeV_above_10MeV

hist_hE_1500MeV_above_20MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1500MeV_above_20MeV.GetNbinsX())
scaled_hist_hE_1500MeV_above_20MeV=normalized_peak_height/hist_hE_1500MeV_above_20MeV.GetBinContent(hist_hE_1500MeV_above_20MeV.GetMaximumBin())*hist_hE_1500MeV_above_20MeV

# %%
hist_hE_2000MeV_above_0MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_2000MeV_above_0MeV.GetNbinsX())
scaled_hist_hE_2000MeV_above_0MeV=normalized_peak_height/hist_hE_2000MeV_above_0MeV.GetBinContent(hist_hE_2000MeV_above_0MeV.GetMaximumBin())*hist_hE_2000MeV_above_0MeV

hist_hE_2000MeV_above_10MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_2000MeV_above_10MeV.GetNbinsX())
scaled_hist_hE_2000MeV_above_10MeV=normalized_peak_height/hist_hE_2000MeV_above_10MeV.GetBinContent(hist_hE_2000MeV_above_10MeV.GetMaximumBin())*hist_hE_2000MeV_above_10MeV

hist_hE_2000MeV_above_20MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_2000MeV_above_20MeV.GetNbinsX())
scaled_hist_hE_2000MeV_above_20MeV=normalized_peak_height/hist_hE_2000MeV_above_20MeV.GetBinContent(hist_hE_2000MeV_above_20MeV.GetMaximumBin())*hist_hE_2000MeV_above_20MeV

# %%
# %jsroot on
canvas=TCanvas("hE","Hit Energy",0,0,2000,2000)
canvas.Divide(2,2)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hE

# %%
canvas.cd(1)

scaled_hist_hE_500MeV_above_0MeV.SetTitle("500 MeV")
scaled_hist_hE_500MeV_above_10MeV.SetTitle("500 MeV")
scaled_hist_hE_500MeV_above_20MeV.SetTitle("500 MeV")

scaled_hist_hE_500MeV_above_0MeV.SetLineColor(4)
scaled_hist_hE_500MeV_above_10MeV.SetLineColor(2)
scaled_hist_hE_500MeV_above_20MeV.SetLineColor(6)

scaled_hist_hE_500MeV_above_0MeV.Draw("same hist")
scaled_hist_hE_500MeV_above_10MeV.Draw("same hist")
scaled_hist_hE_500MeV_above_20MeV.Draw("same hist")

scaled_hist_hE_500MeV_above_0MeV.SetStats(0)
scaled_hist_hE_500MeV_above_10MeV.SetStats(0)
scaled_hist_hE_500MeV_above_20MeV.SetStats(0)

legend_500MeV=TLegend(0.6,0.7,0.9,0.9)

legend_500MeV.AddEntry(scaled_hist_hE_500MeV_above_0MeV,"above_0MeV")
legend_500MeV.AddEntry(scaled_hist_hE_500MeV_above_10MeV,"above_10MeV")
legend_500MeV.AddEntry(scaled_hist_hE_500MeV_above_20MeV,"above_20MeV")
legend_500MeV.SetHeader("Hit Energies","C")
legend_500MeV.Draw()


scaled_hist_hE_500MeV_above_0MeV.GetXaxis().SetRange(0,scaled_hist_hE_500MeV_above_0MeV.GetNbinsX())
scaled_hist_hE_500MeV_above_10MeV.GetXaxis().SetRange(0,scaled_hist_hE_500MeV_above_10MeV.GetNbinsX())
scaled_hist_hE_500MeV_above_20MeV.GetXaxis().SetRange(0,scaled_hist_hE_500MeV_above_20MeV.GetNbinsX())
hist_500MeV_global_max_list=[scaled_hist_hE_500MeV_above_0MeV.GetBinContent(scaled_hist_hE_500MeV_above_0MeV.GetMaximumBin()),
                         scaled_hist_hE_500MeV_above_10MeV.GetBinContent(scaled_hist_hE_500MeV_above_10MeV.GetMaximumBin()),
                         scaled_hist_hE_500MeV_above_20MeV.GetBinContent(scaled_hist_hE_500MeV_above_20MeV.GetMaximumBin())]
scaled_hist_hE_500MeV_above_0MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_500MeV_global_max_list)/100)*100+100)
scaled_hist_hE_500MeV_above_10MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_500MeV_global_max_list)/100)*100+100)
scaled_hist_hE_500MeV_above_20MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_500MeV_global_max_list)/100)*100+100)

# %%
canvas.cd(2)

scaled_hist_hE_1000MeV_above_0MeV.SetTitle("1000 MeV")
scaled_hist_hE_1000MeV_above_10MeV.SetTitle("1000 MeV")
scaled_hist_hE_1000MeV_above_20MeV.SetTitle("1000 MeV")

scaled_hist_hE_1000MeV_above_0MeV.SetLineColor(4)
scaled_hist_hE_1000MeV_above_10MeV.SetLineColor(2)
scaled_hist_hE_1000MeV_above_20MeV.SetLineColor(6)

scaled_hist_hE_1000MeV_above_0MeV.Draw("same hist")
scaled_hist_hE_1000MeV_above_10MeV.Draw("same hist")
scaled_hist_hE_1000MeV_above_20MeV.Draw("same hist")

scaled_hist_hE_1000MeV_above_0MeV.SetStats(0)
scaled_hist_hE_1000MeV_above_10MeV.SetStats(0)
scaled_hist_hE_1000MeV_above_20MeV.SetStats(0)

legend_1000MeV=TLegend(0.6,0.7,0.9,0.9)

legend_1000MeV.AddEntry(scaled_hist_hE_1000MeV_above_0MeV,"above 0MeV")
legend_1000MeV.AddEntry(scaled_hist_hE_1000MeV_above_10MeV,"above 10MeV")
legend_1000MeV.AddEntry(scaled_hist_hE_1000MeV_above_20MeV,"above 20MeV")
legend_1000MeV.SetHeader("Hit Energies","C")
legend_1000MeV.Draw()


scaled_hist_hE_1000MeV_above_0MeV.GetXaxis().SetRange(0,scaled_hist_hE_1000MeV_above_0MeV.GetNbinsX())
scaled_hist_hE_1000MeV_above_10MeV.GetXaxis().SetRange(0,scaled_hist_hE_1000MeV_above_10MeV.GetNbinsX())
scaled_hist_hE_1000MeV_above_20MeV.GetXaxis().SetRange(0,scaled_hist_hE_1000MeV_above_20MeV.GetNbinsX())
hist_1000MeV_global_max_list=[scaled_hist_hE_1000MeV_above_0MeV.GetBinContent(scaled_hist_hE_1000MeV_above_0MeV.GetMaximumBin()),
                         scaled_hist_hE_1000MeV_above_10MeV.GetBinContent(scaled_hist_hE_1000MeV_above_10MeV.GetMaximumBin()),
                         scaled_hist_hE_1000MeV_above_20MeV.GetBinContent(scaled_hist_hE_1000MeV_above_20MeV.GetMaximumBin())]
scaled_hist_hE_1000MeV_above_0MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000MeV_global_max_list)/100)*100+100)
scaled_hist_hE_1000MeV_above_10MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000MeV_global_max_list)/100)*100+100)
scaled_hist_hE_1000MeV_above_20MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000MeV_global_max_list)/100)*100+100)

# %%
canvas.cd(3)

scaled_hist_hE_1500MeV_above_0MeV.SetTitle("1500 MeV")
scaled_hist_hE_1500MeV_above_10MeV.SetTitle("1500 MeV")
scaled_hist_hE_1500MeV_above_20MeV.SetTitle("1500 MeV")

scaled_hist_hE_1500MeV_above_0MeV.SetLineColor(4)
scaled_hist_hE_1500MeV_above_10MeV.SetLineColor(2)
scaled_hist_hE_1500MeV_above_20MeV.SetLineColor(6)

scaled_hist_hE_1500MeV_above_0MeV.Draw("same hist")
scaled_hist_hE_1500MeV_above_10MeV.Draw("same hist")
scaled_hist_hE_1500MeV_above_20MeV.Draw("same hist")

scaled_hist_hE_1500MeV_above_0MeV.SetStats(0)
scaled_hist_hE_1500MeV_above_10MeV.SetStats(0)
scaled_hist_hE_1500MeV_above_20MeV.SetStats(0)

legend_1500MeV=TLegend(0.6,0.7,0.9,0.9)
legend_1500MeV.SetHeader("Hit Energies","C")
legend_1500MeV.AddEntry(scaled_hist_hE_1500MeV_above_0MeV,"above 0MeV")
legend_1500MeV.AddEntry(scaled_hist_hE_1500MeV_above_10MeV,"above 10MeV")
legend_1500MeV.AddEntry(scaled_hist_hE_1500MeV_above_20MeV,"above 20MeV")

legend_1500MeV.Draw()


scaled_hist_hE_1500MeV_above_0MeV.GetXaxis().SetRange(0,scaled_hist_hE_1500MeV_above_0MeV.GetNbinsX())
scaled_hist_hE_1500MeV_above_10MeV.GetXaxis().SetRange(0,scaled_hist_hE_1500MeV_above_10MeV.GetNbinsX())
scaled_hist_hE_1500MeV_above_20MeV.GetXaxis().SetRange(0,scaled_hist_hE_1500MeV_above_20MeV.GetNbinsX())
hist_1500MeV_global_max_list=[scaled_hist_hE_1500MeV_above_0MeV.GetBinContent(scaled_hist_hE_1500MeV_above_0MeV.GetMaximumBin()),
                         scaled_hist_hE_1500MeV_above_10MeV.GetBinContent(scaled_hist_hE_1500MeV_above_10MeV.GetMaximumBin()),
                         scaled_hist_hE_1500MeV_above_20MeV.GetBinContent(scaled_hist_hE_1500MeV_above_20MeV.GetMaximumBin())]
scaled_hist_hE_1500MeV_above_0MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1500MeV_global_max_list)/100)*100+100)
scaled_hist_hE_1500MeV_above_10MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1500MeV_global_max_list)/100)*100+100)
scaled_hist_hE_1500MeV_above_20MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1500MeV_global_max_list)/100)*100+100)

# %%
canvas.cd(4)

scaled_hist_hE_2000MeV_above_0MeV.SetTitle("2000MeV")
scaled_hist_hE_2000MeV_above_10MeV.SetTitle("2000MeV")
scaled_hist_hE_2000MeV_above_20MeV.SetTitle("2000MeV")

scaled_hist_hE_2000MeV_above_0MeV.SetLineColor(4)
scaled_hist_hE_2000MeV_above_10MeV.SetLineColor(2)
scaled_hist_hE_2000MeV_above_20MeV.SetLineColor(6)

scaled_hist_hE_2000MeV_above_0MeV.Draw("same hist")
scaled_hist_hE_2000MeV_above_10MeV.Draw("same hist")
scaled_hist_hE_2000MeV_above_20MeV.Draw("same hist")

scaled_hist_hE_2000MeV_above_0MeV.SetStats(0)
scaled_hist_hE_2000MeV_above_10MeV.SetStats(0)
scaled_hist_hE_2000MeV_above_20MeV.SetStats(0)

legend_2000MeV=TLegend(0.6,0.7,0.9,0.9)
legend_2000MeV.SetHeader("Hit Energies","C")
legend_2000MeV.AddEntry(scaled_hist_hE_2000MeV_above_0MeV,"above 0MeV")
legend_2000MeV.AddEntry(scaled_hist_hE_2000MeV_above_10MeV,"above 10MeV")
legend_2000MeV.AddEntry(scaled_hist_hE_2000MeV_above_20MeV,"above 20MeV")

legend_2000MeV.Draw()


scaled_hist_hE_2000MeV_above_0MeV.GetXaxis().SetRange(0,scaled_hist_hE_2000MeV_above_0MeV.GetNbinsX())
scaled_hist_hE_2000MeV_above_10MeV.GetXaxis().SetRange(0,scaled_hist_hE_2000MeV_above_10MeV.GetNbinsX())
scaled_hist_hE_2000MeV_above_20MeV.GetXaxis().SetRange(0,scaled_hist_hE_2000MeV_above_20MeV.GetNbinsX())
hist_2000MeV_global_max_list=[scaled_hist_hE_2000MeV_above_0MeV.GetBinContent(scaled_hist_hE_2000MeV_above_0MeV.GetMaximumBin()),
                         scaled_hist_hE_2000MeV_above_10MeV.GetBinContent(scaled_hist_hE_2000MeV_above_10MeV.GetMaximumBin()),
                         scaled_hist_hE_2000MeV_above_20MeV.GetBinContent(scaled_hist_hE_2000MeV_above_20MeV.GetMaximumBin())]
scaled_hist_hE_2000MeV_above_0MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_2000MeV_global_max_list)/100)*100+100)
scaled_hist_hE_2000MeV_above_10MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_2000MeV_global_max_list)/100)*100+100)
scaled_hist_hE_2000MeV_above_20MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_2000MeV_global_max_list)/100)*100+100)

# %%
canvas.Draw()
canvas.SaveAs("energy_filtering_only_protons.png")
# Out:
# Info in <TCanvas::Print>: png file energy_filtering_only_protons.png has been created
# <div id="root_plot_1713961083552" style="width: 2000px; height: 2000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1713961083552(Core) {
# ...

# %%
#y-value cut-off factor for fits
fit_selection_scale=0.9
fit_selection_value=normalized_peak_height*fit_selection_scale

# %%
scaled_hist_hE_500MeV_above_0MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_500MeV_above_0MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_500MeV_above_0MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_above_0MeV.GetNbinsX())),
                         scaled_hist_hE_500MeV_above_0MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_500MeV_above_0MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_above_0MeV.GetNbinsX())))
scaled_hist_hE_500MeV_above_10MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_500MeV_above_10MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_500MeV_above_10MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_above_10MeV.GetNbinsX())),
                        scaled_hist_hE_500MeV_above_10MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_500MeV_above_10MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_above_10MeV.GetNbinsX())))
scaled_hist_hE_500MeV_above_20MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_500MeV_above_20MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_500MeV_above_20MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_above_20MeV.GetNbinsX())),
                        scaled_hist_hE_500MeV_above_20MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_500MeV_above_20MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_above_20MeV.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =       12.211
# NDf                       =           11
# Edm                       =   1.8413e-06
# NCalls                    =          142
# Constant                  =      967.834   +/-   5.81002
# Mean                      =      15.2618   +/-   0.0869173
# Sigma                     =       4.0081   +/-   0.454029     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      17.3507
# NDf                       =            9
# Edm                       =  5.87589e-06
# NCalls                    =          169
# Constant                  =      973.496   +/-   5.70254
# Mean                      =      14.8643   +/-   0.266913
# Sigma                     =      4.53071   +/-   0.975352     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
scaled_hist_hE_1000MeV_above_0MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_1000MeV_above_0MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_1000MeV_above_0MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_above_0MeV.GetNbinsX())),
                         scaled_hist_hE_1000MeV_above_0MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_1000MeV_above_0MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_above_0MeV.GetNbinsX())))
scaled_hist_hE_1000MeV_above_10MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_1000MeV_above_10MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1000MeV_above_10MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_above_10MeV.GetNbinsX())),
                        scaled_hist_hE_1000MeV_above_10MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1000MeV_above_10MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_above_10MeV.GetNbinsX())))
scaled_hist_hE_1000MeV_above_20MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_1000MeV_above_20MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1000MeV_above_20MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_above_20MeV.GetNbinsX())),
                        scaled_hist_hE_1000MeV_above_20MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1000MeV_above_20MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_above_20MeV.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      38.0364
# NDf                       =           10
# Edm                       =  1.66417e-05
# NCalls                    =          131
# Constant                  =      978.279   +/-   4.16792
# Mean                      =      11.5856   +/-   0.0461205
# Sigma                     =      3.35468   +/-   0.22545      	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =       28.494
# NDf                       =            9
# Edm                       =  1.72181e-06
# NCalls                    =          141
# Constant                  =        977.4   +/-   4.2763
# Mean                      =      11.4788   +/-   0.049576
# Sigma                     =      3.27797   +/-   0.247885     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
scaled_hist_hE_1500MeV_above_0MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_1500MeV_above_0MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_1500MeV_above_0MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_above_0MeV.GetNbinsX())),
                         scaled_hist_hE_1500MeV_above_0MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_1500MeV_above_0MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_above_0MeV.GetNbinsX())))
scaled_hist_hE_1500MeV_above_10MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_1500MeV_above_10MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1500MeV_above_10MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_above_10MeV.GetNbinsX())),
                        scaled_hist_hE_1500MeV_above_10MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1500MeV_above_10MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_above_10MeV.GetNbinsX())))
scaled_hist_hE_1500MeV_above_20MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_1500MeV_above_20MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1500MeV_above_20MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_above_20MeV.GetNbinsX())),
                        scaled_hist_hE_1500MeV_above_20MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1500MeV_above_20MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_above_20MeV.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      41.8532
# NDf                       =           13
# Edm                       =  4.37016e-07
# NCalls                    =          169
# Constant                  =      985.433   +/-   2.90332
# Mean                      =      10.2021   +/-   0.0821137
# Sigma                     =      4.46742   +/-   0.257302     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      24.4097
# NDf                       =            7
# Edm                       =  9.74851e-09
# NCalls                    =          168
# Constant                  =      980.045   +/-   3.72748
# Mean                      =      10.8943   +/-   0.0571185
# Sigma                     =      2.78769   +/-   0.204124     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
scaled_hist_hE_2000MeV_above_0MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_2000MeV_above_0MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_2000MeV_above_0MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_2000MeV_above_0MeV.GetNbinsX())),
                         scaled_hist_hE_2000MeV_above_0MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_2000MeV_above_0MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_2000MeV_above_0MeV.GetNbinsX())))
scaled_hist_hE_2000MeV_above_10MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_2000MeV_above_10MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_2000MeV_above_10MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_2000MeV_above_10MeV.GetNbinsX())),
                        scaled_hist_hE_2000MeV_above_10MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_2000MeV_above_10MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_2000MeV_above_10MeV.GetNbinsX())))
scaled_hist_hE_2000MeV_above_20MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_2000MeV_above_20MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_2000MeV_above_20MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_2000MeV_above_20MeV.GetNbinsX())),
                        scaled_hist_hE_2000MeV_above_20MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_2000MeV_above_20MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_2000MeV_above_20MeV.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      33.2809
# NDf                       =            8
# Edm                       =  1.29617e-08
# NCalls                    =          177
# Constant                  =      982.447   +/-   3.18977
# Mean                      =      9.79329   +/-   0.0630254
# Sigma                     =      3.42975   +/-   0.263176     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      10.1827
# NDf                       =            5
# Edm                       =  6.10552e-07
# NCalls                    =          150
# Constant                  =      992.629   +/-   3.8415
# Mean                      =      10.7432   +/-   0.0473695
# Sigma                     =      2.18345   +/-   0.162412     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# ...

# %%
peak_position_hE_500MeV_above_0MeV=scaled_hist_hE_500MeV_above_0MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_500MeV_above_10MeV=scaled_hist_hE_500MeV_above_10MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_500MeV_above_20MeV=scaled_hist_hE_500MeV_above_20MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_500MeV=[peak_position_hE_500MeV_above_0MeV,
                         peak_position_hE_500MeV_above_10MeV,
                         peak_position_hE_500MeV_above_20MeV]
array_peak_positions_500MeV
# Out:
# [15.261780496106788, 14.86434103167822, 20.44918484906063]

# %%
peak_position_hE_1000MeV_above_0MeV=scaled_hist_hE_1000MeV_above_0MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1000MeV_above_10MeV=scaled_hist_hE_1000MeV_above_10MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1000MeV_above_20MeV=scaled_hist_hE_1000MeV_above_20MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_1000MeV=[peak_position_hE_1000MeV_above_0MeV,
                         peak_position_hE_1000MeV_above_10MeV,
                         peak_position_hE_1000MeV_above_20MeV]
array_peak_positions_1000MeV
# Out:
# [11.585631962148174, 11.478771500449719, 20.415208173338378]

# %%
peak_position_hE_1500MeV_above_0MeV=scaled_hist_hE_1500MeV_above_0MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1500MeV_above_10MeV=scaled_hist_hE_1500MeV_above_10MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1500MeV_above_20MeV=scaled_hist_hE_1500MeV_above_20MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_1500MeV=[peak_position_hE_1500MeV_above_0MeV,
                         peak_position_hE_1500MeV_above_10MeV,
                         peak_position_hE_1500MeV_above_20MeV]
array_peak_positions_1500MeV
# Out:
# [10.202146589427297, 10.894291132980467, 20.452048016365115]

# %%
peak_position_hE_2000MeV_above_0MeV=scaled_hist_hE_2000MeV_above_0MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_2000MeV_above_10MeV=scaled_hist_hE_2000MeV_above_10MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_2000MeV_above_20MeV=scaled_hist_hE_2000MeV_above_20MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_hE_2000MeV_above_20MeV=[peak_position_hE_2000MeV_above_0MeV,
                         peak_position_hE_2000MeV_above_10MeV,
                         peak_position_hE_2000MeV_above_20MeV]
array_peak_positions_hE_2000MeV_above_20MeV
# Out:
# [9.79328610908924, 10.743186660246879, 20.520092869605076]

# %%
template_root_file=TFile("energy_filtering_only_protons.root","RECREATE")

template_root_file.WriteObject(scaled_hist_hE_500MeV_above_0MeV,"500MeV_above_0MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_500MeV_above_10MeV,"500MeV_above_10MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_500MeV_above_20MeV,"500MeV_above_20MeV_HitEnergy_Hist")

template_root_file.WriteObject(scaled_hist_hE_1000MeV_above_0MeV,"1000MeV_above_0MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1000MeV_above_10MeV,"1000MeV_above_10MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1000MeV_above_20MeV,"1000MeV_above_20MeV_HitEnergy_Hist")

template_root_file.WriteObject(scaled_hist_hE_1500MeV_above_0MeV,"1500MeV_above_0MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1500MeV_above_10MeV,"1500MeV_above_10MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1500MeV_above_20MeV,"1500MeV_above_20MeV_HitEnergy_Hist")

template_root_file.WriteObject(scaled_hist_hE_2000MeV_above_0MeV,"2000MeV_above_0MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_2000MeV_above_10MeV,"2000MeV_above_10MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_2000MeV_above_20MeV,"2000MeV_above_20MeV_HitEnergy_Hist")

template_root_file.Close()
