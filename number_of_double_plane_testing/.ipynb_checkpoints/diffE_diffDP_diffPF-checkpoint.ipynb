# %%
import ROOT, math, time
from ROOT import TFile, TCanvas, TLegend, TLatex
# Out:
# Welcome to JupyROOT 6.30/02

# %%
root_file_path="./20240426-142530-diffE_diffDP_diffPF.root"
root_file=TFile(root_file_path,"read")
root_file.ls()
# Out:
# TFile**		./20240426-142530-diffE_diffDP_diffPF.root
#  TFile*		./20240426-142530-diffE_diffDP_diffPF.root
#   KEY: TH1D	all_p_500MeV_13DP_HitEnergy_Hist;1	all_p_500MeV
#   KEY: TH1D	all_p_500MeV_1DP_HitEnergy_Hist;1	all_p_500MeV
#   KEY: TH1D	all_p_600MeV_13DP_HitEnergy_Hist;1	all_p_600MeV
#   KEY: TH1D	all_p_600MeV_1DP_HitEnergy_Hist;1	all_p_600MeV
#   KEY: TH1D	all_p_700MeV_13DP_HitEnergy_Hist;1	all_p_700MeV
#   KEY: TH1D	all_p_700MeV_1DP_HitEnergy_Hist;1	all_p_700MeV
#   KEY: TH1D	only_pr_500MeV_13DP_HitEnergy_Hist;1	only_pr_500MeV
#   KEY: TH1D	only_pr_500MeV_1DP_HitEnergy_Hist;1	only_pr_500MeV
#   KEY: TH1D	only_pr_600MeV_13DP_HitEnergy_Hist;1	only_pr_600MeV
#   KEY: TH1D	only_pr_600MeV_1DP_HitEnergy_Hist;1	only_pr_600MeV
#   KEY: TH1D	only_pr_700MeV_13DP_HitEnergy_Hist;1	only_pr_700MeV
#   KEY: TH1D	only_pr_700MeV_1DP_HitEnergy_Hist;1	only_pr_700MeV
#   KEY: TH1D	no_pr_500MeV_13DP_HitEnergy_Hist;1	no_pr_500MeV
#   KEY: TH1D	no_pr_500MeV_1DP_HitEnergy_Hist;1	no_pr_500MeV
# ...

# %%
hist_hE_all_p_500MeV_13DP=root_file.Get("all_p_500MeV_13DP_HitEnergy_Hist")

hist_hE_all_p_500MeV_1DP=root_file.Get("all_p_500MeV_1DP_HitEnergy_Hist")

# %%
hist_hE_all_p_600MeV_13DP=root_file.Get("all_p_600MeV_13DP_HitEnergy_Hist")

hist_hE_all_p_600MeV_1DP=root_file.Get("all_p_600MeV_1DP_HitEnergy_Hist")

# %%
hist_hE_all_p_700MeV_13DP=root_file.Get("all_p_700MeV_13DP_HitEnergy_Hist")

hist_hE_all_p_700MeV_1DP=root_file.Get("all_p_700MeV_1DP_HitEnergy_Hist")

# %%
hist_hE_only_pr_500MeV_13DP=root_file.Get("only_pr_500MeV_13DP_HitEnergy_Hist")

hist_hE_only_pr_500MeV_1DP=root_file.Get("only_pr_500MeV_1DP_HitEnergy_Hist")

# %%
hist_hE_only_pr_600MeV_13DP=root_file.Get("only_pr_600MeV_13DP_HitEnergy_Hist")

hist_hE_only_pr_600MeV_1DP=root_file.Get("only_pr_600MeV_1DP_HitEnergy_Hist")

# %%
hist_hE_only_pr_700MeV_13DP=root_file.Get("only_pr_700MeV_13DP_HitEnergy_Hist")

hist_hE_only_pr_700MeV_1DP=root_file.Get("only_pr_700MeV_1DP_HitEnergy_Hist")

# %%
hist_hE_no_pr_500MeV_13DP=root_file.Get("no_pr_500MeV_13DP_HitEnergy_Hist")

hist_hE_no_pr_500MeV_1DP=root_file.Get("no_pr_500MeV_1DP_HitEnergy_Hist")

# %%
hist_hE_no_pr_600MeV_13DP=root_file.Get("no_pr_600MeV_13DP_HitEnergy_Hist")

hist_hE_no_pr_600MeV_1DP=root_file.Get("no_pr_600MeV_1DP_HitEnergy_Hist")

# %%
hist_hE_no_pr_700MeV_13DP=root_file.Get("no_pr_700MeV_13DP_HitEnergy_Hist")

hist_hE_no_pr_700MeV_1DP=root_file.Get("no_pr_700MeV_1DP_HitEnergy_Hist")

# %%
#We want to scale the histograms so they all have a value of 1000 at the main peak of the data.

#set aall_p_700MeVordingly to cut out the first big peak in the data aall_p_700MeVording to bin number
lower_peak_bin=42

#set the value the peaks should be normalised to
normalized_peak_height=1000

# %%
hist_hE_all_p_500MeV_13DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_all_p_500MeV_13DP.GetNbinsX())
scaled_hist_hE_all_p_500MeV_13DP=normalized_peak_height/hist_hE_all_p_500MeV_13DP.GetBinContent(hist_hE_all_p_500MeV_13DP.GetMaximumBin())*hist_hE_all_p_500MeV_13DP

hist_hE_all_p_500MeV_1DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_all_p_500MeV_1DP.GetNbinsX())
scaled_hist_hE_all_p_500MeV_1DP=normalized_peak_height/hist_hE_all_p_500MeV_1DP.GetBinContent(hist_hE_all_p_500MeV_1DP.GetMaximumBin())*hist_hE_all_p_500MeV_1DP

# %%
hist_hE_all_p_600MeV_13DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_all_p_600MeV_13DP.GetNbinsX())
scaled_hist_hE_all_p_600MeV_13DP=normalized_peak_height/hist_hE_all_p_600MeV_13DP.GetBinContent(hist_hE_all_p_600MeV_13DP.GetMaximumBin())*hist_hE_all_p_600MeV_13DP

hist_hE_all_p_600MeV_1DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_all_p_600MeV_1DP.GetNbinsX())
scaled_hist_hE_all_p_600MeV_1DP=normalized_peak_height/hist_hE_all_p_600MeV_1DP.GetBinContent(hist_hE_all_p_600MeV_1DP.GetMaximumBin())*hist_hE_all_p_600MeV_1DP

# %%
hist_hE_all_p_700MeV_13DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_all_p_700MeV_13DP.GetNbinsX())
scaled_hist_hE_all_p_700MeV_13DP=normalized_peak_height/hist_hE_all_p_700MeV_13DP.GetBinContent(hist_hE_all_p_700MeV_13DP.GetMaximumBin())*hist_hE_all_p_700MeV_13DP

hist_hE_all_p_700MeV_1DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_all_p_700MeV_1DP.GetNbinsX())
scaled_hist_hE_all_p_700MeV_1DP=normalized_peak_height/hist_hE_all_p_700MeV_1DP.GetBinContent(hist_hE_all_p_700MeV_1DP.GetMaximumBin())*hist_hE_all_p_700MeV_1DP

# %%
hist_hE_only_pr_500MeV_13DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_only_pr_500MeV_13DP.GetNbinsX())
scaled_hist_hE_only_pr_500MeV_13DP=normalized_peak_height/hist_hE_only_pr_500MeV_13DP.GetBinContent(hist_hE_only_pr_500MeV_13DP.GetMaximumBin())*hist_hE_only_pr_500MeV_13DP

hist_hE_only_pr_500MeV_1DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_only_pr_500MeV_1DP.GetNbinsX())
scaled_hist_hE_only_pr_500MeV_1DP=normalized_peak_height/hist_hE_only_pr_500MeV_1DP.GetBinContent(hist_hE_only_pr_500MeV_1DP.GetMaximumBin())*hist_hE_only_pr_500MeV_1DP

# %%
hist_hE_only_pr_600MeV_13DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_only_pr_600MeV_13DP.GetNbinsX())
scaled_hist_hE_only_pr_600MeV_13DP=normalized_peak_height/hist_hE_only_pr_600MeV_13DP.GetBinContent(hist_hE_only_pr_600MeV_13DP.GetMaximumBin())*hist_hE_only_pr_600MeV_13DP

hist_hE_only_pr_600MeV_1DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_only_pr_600MeV_1DP.GetNbinsX())
scaled_hist_hE_only_pr_600MeV_1DP=normalized_peak_height/hist_hE_only_pr_600MeV_1DP.GetBinContent(hist_hE_only_pr_600MeV_1DP.GetMaximumBin())*hist_hE_only_pr_600MeV_1DP

# %%
hist_hE_only_pr_700MeV_13DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_only_pr_700MeV_13DP.GetNbinsX())
scaled_hist_hE_only_pr_700MeV_13DP=normalized_peak_height/hist_hE_only_pr_700MeV_13DP.GetBinContent(hist_hE_only_pr_700MeV_13DP.GetMaximumBin())*hist_hE_only_pr_700MeV_13DP

hist_hE_only_pr_700MeV_1DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_only_pr_700MeV_1DP.GetNbinsX())
scaled_hist_hE_only_pr_700MeV_1DP=normalized_peak_height/hist_hE_only_pr_700MeV_1DP.GetBinContent(hist_hE_only_pr_700MeV_1DP.GetMaximumBin())*hist_hE_only_pr_700MeV_1DP

# %%
hist_hE_no_pr_500MeV_13DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_pr_500MeV_13DP.GetNbinsX())
scaled_hist_hE_no_pr_500MeV_13DP=normalized_peak_height/hist_hE_no_pr_500MeV_13DP.GetBinContent(hist_hE_no_pr_500MeV_13DP.GetMaximumBin())*hist_hE_no_pr_500MeV_13DP

hist_hE_no_pr_500MeV_1DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_pr_500MeV_1DP.GetNbinsX())
scaled_hist_hE_no_pr_500MeV_1DP=normalized_peak_height/hist_hE_no_pr_500MeV_1DP.GetBinContent(hist_hE_no_pr_500MeV_1DP.GetMaximumBin())*hist_hE_no_pr_500MeV_1DP

# %%
hist_hE_no_pr_600MeV_13DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_pr_600MeV_13DP.GetNbinsX())
scaled_hist_hE_no_pr_600MeV_13DP=normalized_peak_height/hist_hE_no_pr_600MeV_13DP.GetBinContent(hist_hE_no_pr_600MeV_13DP.GetMaximumBin())*hist_hE_no_pr_600MeV_13DP

hist_hE_no_pr_600MeV_1DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_pr_600MeV_1DP.GetNbinsX())
scaled_hist_hE_no_pr_600MeV_1DP=normalized_peak_height/hist_hE_no_pr_600MeV_1DP.GetBinContent(hist_hE_no_pr_600MeV_1DP.GetMaximumBin())*hist_hE_no_pr_600MeV_1DP

# %%
hist_hE_no_pr_700MeV_13DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_pr_700MeV_13DP.GetNbinsX())
scaled_hist_hE_no_pr_700MeV_13DP=normalized_peak_height/hist_hE_no_pr_700MeV_13DP.GetBinContent(hist_hE_no_pr_700MeV_13DP.GetMaximumBin())*hist_hE_no_pr_700MeV_13DP

hist_hE_no_pr_700MeV_1DP.GetXaxis().SetRange(lower_peak_bin,hist_hE_no_pr_700MeV_1DP.GetNbinsX())
scaled_hist_hE_no_pr_700MeV_1DP=normalized_peak_height/hist_hE_no_pr_700MeV_1DP.GetBinContent(hist_hE_no_pr_700MeV_1DP.GetMaximumBin())*hist_hE_no_pr_700MeV_1DP

# %%
# %jsroot on
canvas=TCanvas("hE","Hit Energy",0,0,2000,2000)
canvas.Divide(3,3)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hE

# %%
canvas.cd(1)
scaled_hist_hE_all_p_500MeV_title="all particles, 500 MeV"
legend_all_p_500MeV=TLegend(0.6,0.7,0.9,0.9)
legend_all_p_500MeV.SetHeader("Hit Energies","C")

scaled_hist_hE_all_p_500MeV_13DP.SetTitle(scaled_hist_hE_all_p_500MeV_title)
scaled_hist_hE_all_p_500MeV_13DP.SetLineColor(4)
scaled_hist_hE_all_p_500MeV_13DP.Draw("same hist")
scaled_hist_hE_all_p_500MeV_13DP.SetStats(0)
legend_all_p_500MeV.AddEntry(scaled_hist_hE_all_p_500MeV_13DP,"13DP")

scaled_hist_hE_all_p_500MeV_1DP.SetTitle(scaled_hist_hE_all_p_500MeV_title)
scaled_hist_hE_all_p_500MeV_1DP.SetLineColor(2)
scaled_hist_hE_all_p_500MeV_1DP.Draw("same hist")


scaled_hist_hE_all_p_500MeV_1DP.SetStats(0)
legend_all_p_500MeV.AddEntry(scaled_hist_hE_all_p_500MeV_1DP,"1DP")
hist_all_p_500MeV_global_max_list=[scaled_hist_hE_all_p_500MeV_13DP.GetBinContent(scaled_hist_hE_all_p_500MeV_13DP.GetMaximumBin()),
                         scaled_hist_hE_all_p_500MeV_1DP.GetBinContent(scaled_hist_hE_all_p_500MeV_1DP.GetMaximumBin())]
scaled_hist_hE_all_p_500MeV_1DP.GetXaxis().SetRange(0,scaled_hist_hE_all_p_500MeV_1DP.GetNbinsX())
scaled_hist_hE_all_p_500MeV_1DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_all_p_500MeV_global_max_list)/100)*100+100)
scaled_hist_hE_all_p_500MeV_13DP.GetXaxis().SetRange(0,scaled_hist_hE_all_p_500MeV_13DP.GetNbinsX())
scaled_hist_hE_all_p_500MeV_13DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_all_p_500MeV_global_max_list)/100)*100+100)
legend_all_p_500MeV.Draw()

# %%
canvas.cd(2)
scaled_hist_hE_all_p_600MeV_title="all particles, 600 MeV"
legend_all_p_600MeV=TLegend(0.6,0.7,0.9,0.9)
legend_all_p_600MeV.SetHeader("Hit Energies","C")
hist_all_p_600MeV_global_max_list=[scaled_hist_hE_all_p_600MeV_13DP.GetBinContent(scaled_hist_hE_all_p_600MeV_13DP.GetMaximumBin()),
                         scaled_hist_hE_all_p_600MeV_1DP.GetBinContent(scaled_hist_hE_all_p_600MeV_1DP.GetMaximumBin())]

scaled_hist_hE_all_p_600MeV_13DP.SetTitle(scaled_hist_hE_all_p_600MeV_title)
scaled_hist_hE_all_p_600MeV_13DP.SetLineColor(4)
scaled_hist_hE_all_p_600MeV_13DP.Draw("same hist")
scaled_hist_hE_all_p_600MeV_13DP.SetStats(0)
legend_all_p_600MeV.AddEntry(scaled_hist_hE_all_p_600MeV_13DP,"13DP")


scaled_hist_hE_all_p_600MeV_1DP.SetTitle(scaled_hist_hE_all_p_600MeV_title)
scaled_hist_hE_all_p_600MeV_1DP.SetLineColor(2)
scaled_hist_hE_all_p_600MeV_1DP.Draw("same hist")
scaled_hist_hE_all_p_600MeV_1DP.SetStats(0)
legend_all_p_600MeV.AddEntry(scaled_hist_hE_all_p_600MeV_1DP,"1DP")
scaled_hist_hE_all_p_600MeV_1DP.GetXaxis().SetRange(0,scaled_hist_hE_all_p_600MeV_1DP.GetNbinsX())
scaled_hist_hE_all_p_600MeV_1DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_all_p_600MeV_global_max_list)/100)*100+100)
scaled_hist_hE_all_p_600MeV_13DP.GetXaxis().SetRange(0,scaled_hist_hE_all_p_600MeV_13DP.GetNbinsX())
scaled_hist_hE_all_p_600MeV_13DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_all_p_600MeV_global_max_list)/100)*100+100)



legend_all_p_600MeV.Draw()

# %%
canvas.cd(3)
scaled_hist_hE_all_p_700MeV_title="all particles, 700 MeV"
legend_all_p_700MeV=TLegend(0.6,0.7,0.9,0.9)
legend_all_p_700MeV.SetHeader("Hit Energies","C")
hist_all_p_700MeV_global_max_list=[scaled_hist_hE_all_p_700MeV_13DP.GetBinContent(scaled_hist_hE_all_p_700MeV_13DP.GetMaximumBin()),
                         scaled_hist_hE_all_p_700MeV_1DP.GetBinContent(scaled_hist_hE_all_p_700MeV_1DP.GetMaximumBin())]

scaled_hist_hE_all_p_700MeV_13DP.SetTitle(scaled_hist_hE_all_p_700MeV_title)
scaled_hist_hE_all_p_700MeV_13DP.SetLineColor(4)
scaled_hist_hE_all_p_700MeV_13DP.Draw("same hist")
scaled_hist_hE_all_p_700MeV_13DP.SetStats(0)
legend_all_p_700MeV.AddEntry(scaled_hist_hE_all_p_700MeV_13DP,"13DP")


scaled_hist_hE_all_p_700MeV_1DP.SetTitle(scaled_hist_hE_all_p_700MeV_title)
scaled_hist_hE_all_p_700MeV_1DP.SetLineColor(2)
scaled_hist_hE_all_p_700MeV_1DP.Draw("same hist")
scaled_hist_hE_all_p_700MeV_1DP.SetStats(0)
legend_all_p_700MeV.AddEntry(scaled_hist_hE_all_p_700MeV_1DP,"1DP")
scaled_hist_hE_all_p_700MeV_1DP.GetXaxis().SetRange(0,scaled_hist_hE_all_p_700MeV_1DP.GetNbinsX())
scaled_hist_hE_all_p_700MeV_1DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_all_p_700MeV_global_max_list)/100)*100+100)
scaled_hist_hE_all_p_700MeV_13DP.GetXaxis().SetRange(0,scaled_hist_hE_all_p_700MeV_13DP.GetNbinsX())
scaled_hist_hE_all_p_700MeV_13DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_all_p_700MeV_global_max_list)/100)*100+100)
legend_all_p_700MeV.Draw()

# %%
canvas.cd(4)
scaled_hist_hE_only_pr_500MeV_title="only protons, 500 MeV"
legend_only_pr_500MeV=TLegend(0.6,0.7,0.9,0.9)
legend_only_pr_500MeV.SetHeader("Hit Energies","C")
hist_only_pr_500MeV_global_max_list=[scaled_hist_hE_only_pr_500MeV_13DP.GetBinContent(scaled_hist_hE_only_pr_500MeV_13DP.GetMaximumBin()),
                         scaled_hist_hE_only_pr_500MeV_1DP.GetBinContent(scaled_hist_hE_only_pr_500MeV_1DP.GetMaximumBin())]

scaled_hist_hE_only_pr_500MeV_13DP.SetTitle(scaled_hist_hE_only_pr_500MeV_title)
scaled_hist_hE_only_pr_500MeV_13DP.SetLineColor(4)
scaled_hist_hE_only_pr_500MeV_13DP.Draw("same hist")
scaled_hist_hE_only_pr_500MeV_13DP.SetStats(0)
legend_only_pr_500MeV.AddEntry(scaled_hist_hE_only_pr_500MeV_13DP,"13DP")
scaled_hist_hE_only_pr_500MeV_13DP.GetXaxis().SetRange(0,scaled_hist_hE_only_pr_500MeV_13DP.GetNbinsX())
scaled_hist_hE_only_pr_500MeV_13DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_only_pr_500MeV_global_max_list)/100)*100+100)
scaled_hist_hE_only_pr_500MeV_1DP.GetXaxis().SetRange(0,scaled_hist_hE_only_pr_500MeV_1DP.GetNbinsX())
scaled_hist_hE_only_pr_500MeV_1DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_only_pr_500MeV_global_max_list)/100)*100+100)

scaled_hist_hE_only_pr_500MeV_1DP.SetTitle(scaled_hist_hE_only_pr_500MeV_title)
scaled_hist_hE_only_pr_500MeV_1DP.SetLineColor(2)
scaled_hist_hE_only_pr_500MeV_1DP.Draw("same hist")
scaled_hist_hE_only_pr_500MeV_1DP.SetStats(0)
legend_only_pr_500MeV.AddEntry(scaled_hist_hE_only_pr_500MeV_1DP,"1DP")


legend_only_pr_500MeV.Draw()

# %%
canvas.cd(5)
scaled_hist_hE_only_pr_600MeV_title="only protons, 600 MeV"
legend_only_pr_600MeV=TLegend(0.6,0.7,0.9,0.9)
legend_only_pr_600MeV.SetHeader("Hit Energies","C")
hist_only_pr_600MeV_global_max_list=[scaled_hist_hE_only_pr_600MeV_13DP.GetBinContent(scaled_hist_hE_only_pr_600MeV_13DP.GetMaximumBin()),
                         scaled_hist_hE_only_pr_600MeV_1DP.GetBinContent(scaled_hist_hE_only_pr_600MeV_1DP.GetMaximumBin())]

scaled_hist_hE_only_pr_600MeV_13DP.SetTitle(scaled_hist_hE_only_pr_600MeV_title)
scaled_hist_hE_only_pr_600MeV_13DP.SetLineColor(4)
scaled_hist_hE_only_pr_600MeV_13DP.Draw("same hist")
scaled_hist_hE_only_pr_600MeV_13DP.SetStats(0)
legend_only_pr_600MeV.AddEntry(scaled_hist_hE_only_pr_600MeV_13DP,"13DP")


scaled_hist_hE_only_pr_600MeV_1DP.SetTitle(scaled_hist_hE_only_pr_600MeV_title)
scaled_hist_hE_only_pr_600MeV_1DP.SetLineColor(2)
scaled_hist_hE_only_pr_600MeV_1DP.Draw("same hist")
scaled_hist_hE_only_pr_600MeV_1DP.SetStats(0)
legend_only_pr_600MeV.AddEntry(scaled_hist_hE_only_pr_600MeV_1DP,"1DP")
scaled_hist_hE_only_pr_600MeV_1DP.GetXaxis().SetRange(0,scaled_hist_hE_only_pr_600MeV_1DP.GetNbinsX())
scaled_hist_hE_only_pr_600MeV_1DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_only_pr_600MeV_global_max_list)/100)*100+100)
scaled_hist_hE_only_pr_600MeV_13DP.GetXaxis().SetRange(0,scaled_hist_hE_only_pr_600MeV_13DP.GetNbinsX())
scaled_hist_hE_only_pr_600MeV_13DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_only_pr_600MeV_global_max_list)/100)*100+100)
legend_only_pr_600MeV.Draw()

# %%
canvas.cd(6)
scaled_hist_hE_only_pr_700MeV_title="only protons, 700 MeV"
legend_only_pr_700MeV=TLegend(0.6,0.7,0.9,0.9)
legend_only_pr_700MeV.SetHeader("Hit Energies","C")
hist_only_pr_700MeV_global_max_list=[scaled_hist_hE_only_pr_700MeV_13DP.GetBinContent(scaled_hist_hE_only_pr_700MeV_13DP.GetMaximumBin()),
                         scaled_hist_hE_only_pr_700MeV_1DP.GetBinContent(scaled_hist_hE_only_pr_700MeV_1DP.GetMaximumBin())]

scaled_hist_hE_only_pr_700MeV_13DP.SetTitle(scaled_hist_hE_only_pr_700MeV_title)
scaled_hist_hE_only_pr_700MeV_13DP.SetLineColor(4)
scaled_hist_hE_only_pr_700MeV_13DP.Draw("same hist")
scaled_hist_hE_only_pr_700MeV_13DP.SetStats(0)
legend_only_pr_700MeV.AddEntry(scaled_hist_hE_only_pr_700MeV_13DP,"13DP")


scaled_hist_hE_only_pr_700MeV_1DP.SetTitle(scaled_hist_hE_only_pr_700MeV_title)
scaled_hist_hE_only_pr_700MeV_1DP.SetLineColor(2)
scaled_hist_hE_only_pr_700MeV_1DP.Draw("same hist")
scaled_hist_hE_only_pr_700MeV_1DP.SetStats(0)
legend_only_pr_700MeV.AddEntry(scaled_hist_hE_only_pr_700MeV_1DP,"1DP")
scaled_hist_hE_only_pr_700MeV_1DP.GetXaxis().SetRange(0,scaled_hist_hE_only_pr_700MeV_1DP.GetNbinsX())
scaled_hist_hE_only_pr_700MeV_1DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_only_pr_700MeV_global_max_list)/100)*100+100)
scaled_hist_hE_only_pr_700MeV_13DP.GetXaxis().SetRange(0,scaled_hist_hE_only_pr_700MeV_13DP.GetNbinsX())
scaled_hist_hE_only_pr_700MeV_13DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_only_pr_700MeV_global_max_list)/100)*100+100)
legend_only_pr_700MeV.Draw()

# %%
canvas.cd(7)
scaled_hist_hE_no_pr_500MeV_title="no protons, 500 MeV"
legend_no_pr_500MeV=TLegend(0.6,0.7,0.9,0.9)
legend_no_pr_500MeV.SetHeader("Hit Energies","C")
hist_no_pr_500MeV_global_max_list=[scaled_hist_hE_no_pr_500MeV_13DP.GetBinContent(scaled_hist_hE_no_pr_500MeV_13DP.GetMaximumBin()),
                         scaled_hist_hE_no_pr_500MeV_1DP.GetBinContent(scaled_hist_hE_no_pr_500MeV_1DP.GetMaximumBin())]

scaled_hist_hE_no_pr_500MeV_13DP.SetTitle(scaled_hist_hE_no_pr_500MeV_title)
scaled_hist_hE_no_pr_500MeV_13DP.SetLineColor(4)
scaled_hist_hE_no_pr_500MeV_13DP.Draw("same hist")
scaled_hist_hE_no_pr_500MeV_13DP.SetStats(0)
legend_no_pr_500MeV.AddEntry(scaled_hist_hE_no_pr_500MeV_13DP,"13DP")


scaled_hist_hE_no_pr_500MeV_1DP.SetTitle(scaled_hist_hE_no_pr_500MeV_title)
scaled_hist_hE_no_pr_500MeV_1DP.SetLineColor(2)
scaled_hist_hE_no_pr_500MeV_1DP.Draw("same hist")
scaled_hist_hE_no_pr_500MeV_1DP.SetStats(0)
legend_no_pr_500MeV.AddEntry(scaled_hist_hE_no_pr_500MeV_1DP,"1DP")


scaled_hist_hE_no_pr_500MeV_13DP.GetXaxis().SetRange(0,scaled_hist_hE_no_pr_500MeV_13DP.GetNbinsX())
scaled_hist_hE_no_pr_500MeV_13DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_pr_500MeV_global_max_list)/100)*100+100)
scaled_hist_hE_no_pr_500MeV_1DP.GetXaxis().SetRange(0,scaled_hist_hE_no_pr_500MeV_1DP.GetNbinsX())
scaled_hist_hE_no_pr_500MeV_1DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_pr_500MeV_global_max_list)/100)*100+100)

legend_no_pr_500MeV.Draw()

# %%
canvas.cd(8)
scaled_hist_hE_no_pr_600MeV_title="no protons, 600 MeV"
legend_no_pr_600MeV=TLegend(0.6,0.7,0.9,0.9)
legend_no_pr_600MeV.SetHeader("Hit Energies","C")
hist_no_pr_600MeV_global_max_list=[scaled_hist_hE_no_pr_600MeV_13DP.GetBinContent(scaled_hist_hE_no_pr_600MeV_13DP.GetMaximumBin()),
                                 scaled_hist_hE_no_pr_600MeV_1DP.GetBinContent(scaled_hist_hE_no_pr_600MeV_1DP.GetMaximumBin())]

scaled_hist_hE_no_pr_600MeV_13DP.SetTitle(scaled_hist_hE_no_pr_600MeV_title)
scaled_hist_hE_no_pr_600MeV_13DP.SetLineColor(4)
scaled_hist_hE_no_pr_600MeV_13DP.Draw("same hist")
scaled_hist_hE_no_pr_600MeV_13DP.SetStats(0)
legend_no_pr_600MeV.AddEntry(scaled_hist_hE_no_pr_600MeV_13DP,"13DP")


scaled_hist_hE_no_pr_600MeV_1DP.SetTitle(scaled_hist_hE_no_pr_600MeV_title)
scaled_hist_hE_no_pr_600MeV_1DP.SetLineColor(2)
scaled_hist_hE_no_pr_600MeV_1DP.Draw("same hist")
scaled_hist_hE_no_pr_600MeV_1DP.SetStats(0)
legend_no_pr_600MeV.AddEntry(scaled_hist_hE_no_pr_600MeV_1DP,"1DP")



scaled_hist_hE_no_pr_600MeV_13DP.GetXaxis().SetRange(0,scaled_hist_hE_no_pr_600MeV_13DP.GetNbinsX())
scaled_hist_hE_no_pr_600MeV_13DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_pr_600MeV_global_max_list)/100)*100+100)
scaled_hist_hE_no_pr_600MeV_1DP.GetXaxis().SetRange(0,scaled_hist_hE_no_pr_600MeV_1DP.GetNbinsX())
scaled_hist_hE_no_pr_600MeV_1DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_pr_600MeV_global_max_list)/100)*100+100)

legend_no_pr_600MeV.Draw()

# %%
canvas.cd(9)
scaled_hist_hE_no_pr_700MeV_title="no protons, 700 MeV"
legend_no_pr_700MeV=TLegend(0.6,0.7,0.9,0.9)
legend_no_pr_700MeV.SetHeader("Hit Energies","C")


scaled_hist_hE_no_pr_700MeV_13DP.SetTitle(scaled_hist_hE_no_pr_700MeV_title)
scaled_hist_hE_no_pr_700MeV_13DP.SetLineColor(4)
scaled_hist_hE_no_pr_700MeV_13DP.Draw("same hist")
scaled_hist_hE_no_pr_700MeV_13DP.SetStats(0)
legend_no_pr_700MeV.AddEntry(scaled_hist_hE_no_pr_700MeV_13DP,"13DP")


scaled_hist_hE_no_pr_700MeV_1DP.SetTitle(scaled_hist_hE_no_pr_700MeV_title)
scaled_hist_hE_no_pr_700MeV_1DP.SetLineColor(2)
scaled_hist_hE_no_pr_700MeV_1DP.Draw("same hist")
scaled_hist_hE_no_pr_700MeV_1DP.SetStats(0)
legend_no_pr_700MeV.AddEntry(scaled_hist_hE_no_pr_700MeV_1DP,"1DP")


hist_no_pr_700MeV_global_max_list=[scaled_hist_hE_no_pr_700MeV_13DP.GetBinContent(scaled_hist_hE_no_pr_700MeV_13DP.GetMaximumBin()),
                         scaled_hist_hE_no_pr_700MeV_1DP.GetBinContent(scaled_hist_hE_no_pr_700MeV_1DP.GetMaximumBin())]
scaled_hist_hE_no_pr_700MeV_13DP.GetXaxis().SetRange(0,scaled_hist_hE_no_pr_700MeV_13DP.GetNbinsX())
scaled_hist_hE_no_pr_700MeV_13DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_pr_700MeV_global_max_list)/100)*100+100)
scaled_hist_hE_no_pr_700MeV_1DP.GetXaxis().SetRange(0,scaled_hist_hE_no_pr_700MeV_1DP.GetNbinsX())
scaled_hist_hE_no_pr_700MeV_1DP.GetYaxis().SetRangeUser(0,math.floor(max(hist_no_pr_700MeV_global_max_list)/100)*100+100)

legend_no_pr_700MeV.Draw()

# %%
canvas.Draw()
canvas.SaveAs("diffE_diffDP_diffPF.png")
# Out:
# Info in <TCanvas::Print>: png file diffE_diffDP_diffPF.png has been created
# <div id="root_plot_1714135219914" style="width: 2000px; height: 2000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1714135219914(Core) {
# ...

# %%
#y-value cut-off factor for fits
fit_selection_scale=0.9
fit_selection_value=normalized_peak_height*fit_selection_scale

# %%
scaled_hist_hE_all_p_500MeV_13DP.Fit("gaus","S 0","same",
                         scaled_hist_hE_all_p_500MeV_13DP.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_all_p_500MeV_13DP.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_500MeV_13DP.GetNbinsX())),
                         scaled_hist_hE_all_p_500MeV_13DP.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_all_p_500MeV_13DP.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_500MeV_13DP.GetNbinsX())))
scaled_hist_hE_all_p_500MeV_1DP.Fit("gaus","S 0","same",
                        scaled_hist_hE_all_p_500MeV_1DP.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_all_p_500MeV_1DP.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_500MeV_1DP.GetNbinsX())),
                        scaled_hist_hE_all_p_500MeV_1DP.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_all_p_500MeV_1DP.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_500MeV_1DP.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      10.9715
# NDf                       =           13
# Edm                       =  5.47232e-06
# NCalls                    =          124
# Constant                  =      984.602   +/-   5.64191
# Mean                      =      15.1955   +/-   0.0577657
# Sigma                     =      3.68779   +/-   0.257064     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      40.8565
# NDf                       =           27
# Edm                       =  1.12728e-06
# NCalls                    =          285
# Constant                  =      938.746   +/-   6.94078
# Mean                      =      13.7101   +/-   1.6567
# Sigma                     =      15.3302   +/-   8.66476      	 (limited)

# %%
scaled_hist_hE_all_p_600MeV_13DP.Fit("gaus","S 0","same",
                         scaled_hist_hE_all_p_600MeV_13DP.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_all_p_600MeV_13DP.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_600MeV_13DP.GetNbinsX())),
                         scaled_hist_hE_all_p_600MeV_13DP.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_all_p_600MeV_13DP.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_600MeV_13DP.GetNbinsX())))
scaled_hist_hE_all_p_600MeV_1DP.Fit("gaus","S 0","same",
                        scaled_hist_hE_all_p_600MeV_1DP.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_all_p_600MeV_1DP.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_600MeV_1DP.GetNbinsX())),
                        scaled_hist_hE_all_p_600MeV_1DP.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_all_p_600MeV_1DP.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_600MeV_1DP.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      124.131
# NDf                       =           24
# Edm                       =  1.81319e-06
# NCalls                    =          172
# Constant                  =      960.733   +/-   3.5609
# Mean                      =      13.6788   +/-   0.141871
# Sigma                     =      7.55693   +/-   0.529573     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      15.0146
# NDf                       =           20
# Edm                       =  9.38374e-06
# NCalls                    =          215
# Constant                  =      975.629   +/-   7.50864
# Mean                      =      10.7153   +/-   0.768306
# Sigma                     =      13.2699   +/-   8.80823      	 (limited)

# %%
scaled_hist_hE_all_p_700MeV_13DP.Fit("gaus","S 0","same",
                         scaled_hist_hE_all_p_700MeV_13DP.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_all_p_700MeV_13DP.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_700MeV_13DP.GetNbinsX())),
                         scaled_hist_hE_all_p_700MeV_13DP.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_all_p_700MeV_13DP.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_700MeV_13DP.GetNbinsX())))
scaled_hist_hE_all_p_700MeV_1DP.Fit("gaus","S 0","same",
                        scaled_hist_hE_all_p_700MeV_1DP.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_all_p_700MeV_1DP.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_700MeV_1DP.GetNbinsX())),
                        scaled_hist_hE_all_p_700MeV_1DP.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_all_p_700MeV_1DP.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_all_p_700MeV_1DP.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      35.7462
# NDf                       =           21
# Edm                       =   2.9825e-07
# NCalls                    =          159
# Constant                  =      972.551   +/-   3.61875
# Mean                      =      12.2933   +/-   0.0876009
# Sigma                     =      6.89661   +/-   0.482297     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      18.2413
# NDf                       =           20
# Edm                       =  2.92815e-07
# NCalls                    =          151
# Constant                  =        968.6   +/-   7.73323
# Mean                      =      11.3799   +/-   0.254848
# Sigma                     =      6.80911   +/-   1.13104      	 (limited)

# %%
scaled_hist_hE_only_pr_500MeV_13DP.Fit("gaus","S 0","same",
                         scaled_hist_hE_only_pr_500MeV_13DP.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_only_pr_500MeV_13DP.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_500MeV_13DP.GetNbinsX())),
                         scaled_hist_hE_only_pr_500MeV_13DP.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_only_pr_500MeV_13DP.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_500MeV_13DP.GetNbinsX())))
scaled_hist_hE_only_pr_500MeV_1DP.Fit("gaus","S 0","same",
                        scaled_hist_hE_only_pr_500MeV_1DP.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_only_pr_500MeV_1DP.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_500MeV_1DP.GetNbinsX())),
                        scaled_hist_hE_only_pr_500MeV_1DP.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_only_pr_500MeV_1DP.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_500MeV_1DP.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      11.2171
# NDf                       =           12
# Edm                       =  7.84088e-07
# NCalls                    =          127
# Constant                  =      983.645   +/-   6.66804
# Mean                      =      15.4339   +/-   0.0737478
# Sigma                     =       3.6942   +/-   0.348073     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      53.7779
# NDf                       =           29
# Edm                       =  7.43607e-07
# NCalls                    =          293
# Constant                  =      939.714   +/-   14.8532
# Mean                      =      6.56137   +/-   1.05868
# Sigma                     =      18.5281   +/-   2.44749      	 (limited)

# %%
scaled_hist_hE_only_pr_600MeV_13DP.Fit("gaus","S 0","same",
                         scaled_hist_hE_only_pr_600MeV_13DP.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_only_pr_600MeV_13DP.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_600MeV_13DP.GetNbinsX())),
                         scaled_hist_hE_only_pr_600MeV_13DP.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_only_pr_600MeV_13DP.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_600MeV_13DP.GetNbinsX())))
scaled_hist_hE_only_pr_600MeV_1DP.Fit("gaus","S 0","same",
                        scaled_hist_hE_only_pr_600MeV_1DP.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_only_pr_600MeV_1DP.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_600MeV_1DP.GetNbinsX())),
                        scaled_hist_hE_only_pr_600MeV_1DP.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_only_pr_600MeV_1DP.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_600MeV_1DP.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      26.1811
# NDf                       =           10
# Edm                       =  5.01005e-08
# NCalls                    =          178
# Constant                  =      960.819   +/-   6.38301
# Mean                      =      14.3458   +/-   0.132927
# Sigma                     =      4.48187   +/-   0.810539     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      42.9812
# NDf                       =           24
# Edm                       =  1.30657e-05
# NCalls                    =          279
# Constant                  =       971.91   +/-   17.7333
# Mean                      =      6.66013   +/-   0.857136
# Sigma                     =      15.6239   +/-   2.43689      	 (limited)

# %%
scaled_hist_hE_only_pr_700MeV_13DP.Fit("gaus","S 0","same",
                         scaled_hist_hE_only_pr_700MeV_13DP.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_only_pr_700MeV_13DP.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_700MeV_13DP.GetNbinsX())),
                         scaled_hist_hE_only_pr_700MeV_13DP.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_only_pr_700MeV_13DP.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_700MeV_13DP.GetNbinsX())))
scaled_hist_hE_only_pr_700MeV_1DP.Fit("gaus","S 0","same",
                        scaled_hist_hE_only_pr_700MeV_1DP.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_only_pr_700MeV_1DP.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_700MeV_1DP.GetNbinsX())),
                        scaled_hist_hE_only_pr_700MeV_1DP.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_only_pr_700MeV_1DP.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_only_pr_700MeV_1DP.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      40.8267
# NDf                       =           16
# Edm                       =  6.86269e-07
# NCalls                    =          159
# Constant                  =      979.658   +/-   5.0775
# Mean                      =      13.7105   +/-   0.0951198
# Sigma                     =      5.24515   +/-   0.477274     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =       26.715
# NDf                       =           15
# Edm                       =  1.81884e-06
# NCalls                    =          232
# Constant                  =      970.661   +/-   19.3561
# Mean                      =      7.98522   +/-   0.729359
# Sigma                     =      10.4196   +/-   1.83125      	 (limited)

# %%
scaled_hist_hE_no_pr_500MeV_13DP.Fit("gaus","S 0","same",
                         scaled_hist_hE_no_pr_500MeV_13DP.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_no_pr_500MeV_13DP.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_500MeV_13DP.GetNbinsX())),
                         scaled_hist_hE_no_pr_500MeV_13DP.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_no_pr_500MeV_13DP.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_500MeV_13DP.GetNbinsX())))
scaled_hist_hE_no_pr_500MeV_1DP.Fit("gaus","S 0","same",
                        scaled_hist_hE_no_pr_500MeV_1DP.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_no_pr_500MeV_1DP.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_500MeV_1DP.GetNbinsX())),
                        scaled_hist_hE_no_pr_500MeV_1DP.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_no_pr_500MeV_1DP.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_500MeV_1DP.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      3.07287
# NDf                       =            7
# Edm                       =  5.48955e-08
# NCalls                    =          178
# Constant                  =      997.958   +/-   8.05426
# Mean                      =      8.78833   +/-   0.196961
# Sigma                     =      3.13642   +/-   0.638556     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      4.20471
# NDf                       =            6
# Edm                       =  2.81408e-07
# NCalls                    =          267
# Constant                  =      955.644   +/-   12.9589
# Mean                      =      8.69036   +/-   0.55105
# Sigma                     =      5.15924   +/-   5.14696      	 (limited)

# %%
scaled_hist_hE_no_pr_600MeV_13DP.Fit("gaus","S 0","same",
                         scaled_hist_hE_no_pr_600MeV_13DP.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_no_pr_600MeV_13DP.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_600MeV_13DP.GetNbinsX())),
                         scaled_hist_hE_no_pr_600MeV_13DP.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_no_pr_600MeV_13DP.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_600MeV_13DP.GetNbinsX())))
scaled_hist_hE_no_pr_600MeV_1DP.Fit("gaus","S 0","same",
                        scaled_hist_hE_no_pr_600MeV_1DP.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_no_pr_600MeV_1DP.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_600MeV_1DP.GetNbinsX())),
                        scaled_hist_hE_no_pr_600MeV_1DP.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_no_pr_600MeV_1DP.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_600MeV_1DP.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      6.57145
# NDf                       =            8
# Edm                       =  1.10269e-07
# NCalls                    =          154
# Constant                  =       984.03   +/-   7.19026
# Mean                      =      9.21234   +/-   0.0695225
# Sigma                     =      2.91437   +/-   0.345213     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      7.61047
# NDf                       =            8
# Edm                       =  1.52483e-06
# NCalls                    =          170
# Constant                  =      945.399   +/-   12.4398
# Mean                      =       9.3899   +/-   0.230399
# Sigma                     =       3.9751   +/-   1.50322      	 (limited)

# %%
scaled_hist_hE_no_pr_700MeV_13DP.Fit("gaus","S 0","same",
                         scaled_hist_hE_no_pr_700MeV_13DP.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_no_pr_700MeV_13DP.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_700MeV_13DP.GetNbinsX())),
                         scaled_hist_hE_no_pr_700MeV_13DP.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_no_pr_700MeV_13DP.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_700MeV_13DP.GetNbinsX())))
scaled_hist_hE_no_pr_700MeV_1DP.Fit("gaus","S 0","same",
                        scaled_hist_hE_no_pr_700MeV_1DP.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_no_pr_700MeV_1DP.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_700MeV_1DP.GetNbinsX())),
                        scaled_hist_hE_no_pr_700MeV_1DP.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_no_pr_700MeV_1DP.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_no_pr_700MeV_1DP.GetNbinsX())))
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      6.62517
# NDf                       =            7
# Edm                       =  4.47623e-08
# NCalls                    =          122
# Constant                  =      990.707   +/-   6.64216
# Mean                      =      9.38718   +/-   0.0417166
# Sigma                     =      2.30059   +/-   0.189201     	 (limited)
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      2.43519
# NDf                       =            8
# Edm                       =  1.12359e-09
# NCalls                    =          135
# Constant                  =      991.649   +/-   12.1871
# Mean                      =      9.29549   +/-   0.112925
# Sigma                     =      2.93714   +/-   0.586733     	 (limited)

# %%
array_peak_positions_all_p_500MeV=[]

array_peak_positions_all_p_500MeV.append(scaled_hist_hE_all_p_500MeV_13DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_all_p_500MeV.append(scaled_hist_hE_all_p_500MeV_1DP.GetFunction("gaus").GetParameter("Mean"))

array_peak_positions_all_p_500MeV
# Out:
# [15.195540848388136, 13.710149221546432]

# %%
array_peak_positions_all_p_600MeV=[]

array_peak_positions_all_p_600MeV.append(scaled_hist_hE_all_p_600MeV_13DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_all_p_600MeV.append(scaled_hist_hE_all_p_600MeV_1DP.GetFunction("gaus").GetParameter("Mean"))

array_peak_positions_all_p_600MeV
# Out:
# [13.678824948198418, 10.715256542795535]

# %%
array_peak_positions_all_p_700MeV=[]

array_peak_positions_all_p_700MeV.append(scaled_hist_hE_all_p_700MeV_13DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_all_p_700MeV.append(scaled_hist_hE_all_p_700MeV_1DP.GetFunction("gaus").GetParameter("Mean"))

array_peak_positions_all_p_700MeV
# Out:
# [12.293295307165145, 11.379933111945768]

# %%
array_peak_positions_only_pr_500MeV=[]

array_peak_positions_only_pr_500MeV.append(scaled_hist_hE_only_pr_500MeV_13DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_only_pr_500MeV.append(scaled_hist_hE_only_pr_500MeV_1DP.GetFunction("gaus").GetParameter("Mean"))

array_peak_positions_only_pr_500MeV
# Out:
# [15.433930058028315, 6.561373557988452]

# %%
array_peak_positions_only_pr_600MeV=[]

array_peak_positions_only_pr_600MeV.append(scaled_hist_hE_only_pr_600MeV_13DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_only_pr_600MeV.append(scaled_hist_hE_only_pr_600MeV_1DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_only_pr_600MeV
# Out:
# [14.345805919228802, 6.660129159915158]

# %%
array_peak_positions_only_pr_700MeV=[]

array_peak_positions_only_pr_700MeV.append(scaled_hist_hE_only_pr_700MeV_13DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_only_pr_700MeV.append(scaled_hist_hE_only_pr_700MeV_1DP.GetFunction("gaus").GetParameter("Mean"))

array_peak_positions_only_pr_700MeV
# Out:
# [13.710542278670973, 7.9852230326310085]

# %%
array_peak_positions_no_pr_500MeV=[]

array_peak_positions_no_pr_500MeV.append(scaled_hist_hE_no_pr_500MeV_13DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_no_pr_500MeV.append(scaled_hist_hE_no_pr_500MeV_1DP.GetFunction("gaus").GetParameter("Mean"))

array_peak_positions_no_pr_500MeV
# Out:
# [8.788326822497902, 8.690360299738556]

# %%
array_peak_positions_no_pr_600MeV=[]

array_peak_positions_no_pr_600MeV.append(scaled_hist_hE_no_pr_600MeV_13DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_no_pr_600MeV.append(scaled_hist_hE_no_pr_600MeV_1DP.GetFunction("gaus").GetParameter("Mean"))

array_peak_positions_no_pr_600MeV
# Out:
# [9.212341669829307, 9.38989950068756]

# %%
array_peak_positions_no_pr_700MeV=[]

array_peak_positions_no_pr_700MeV.append(scaled_hist_hE_no_pr_700MeV_13DP.GetFunction("gaus").GetParameter("Mean"))
array_peak_positions_no_pr_700MeV.append(scaled_hist_hE_no_pr_700MeV_1DP.GetFunction("gaus").GetParameter("Mean"))

array_peak_positions_no_pr_700MeV
# Out:
# [9.387175340489675, 9.295490936027829]
