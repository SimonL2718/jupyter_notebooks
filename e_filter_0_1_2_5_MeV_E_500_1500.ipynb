# %%
import ROOT, math
from ROOT import TFile, TCanvas, TLegend, TLatex
# Out:
# Welcome to JupyROOT 6.30/02

# %%
root_file_folder_path="~/test/R3BRoot/build/bin/"

# %%
file_500MeV_0MeV=TFile(root_file_folder_path+"all_particles_above_0MeV_500MeV_n1.root","read")
hist_hE_500MeV_0MeV=file_500MeV_0MeV.GetDirectory("HistMonitor").Get("hE")

file_500MeV_1MeV=TFile(root_file_folder_path+"all_particles_above_1MeV_500MeV_n1.root","read")
hist_hE_500MeV_1MeV=file_500MeV_1MeV.GetDirectory("HistMonitor").Get("hE")

file_500MeV_2MeV=TFile(root_file_folder_path+"all_particles_above_2MeV_500MeV_n1.root","read")
hist_hE_500MeV_2MeV=file_500MeV_2MeV.GetDirectory("HistMonitor").Get("hE")

file_500MeV_5MeV=TFile(root_file_folder_path+"all_particles_above_5MeV_500MeV_n1.root","read")
hist_hE_500MeV_5MeV=file_500MeV_5MeV.GetDirectory("HistMonitor").Get("hE")
# Out:
# Warning in <TClass::Init>: no dictionary for class FairFileHeader is available
# Warning in <TClass::Init>: no dictionary for class FairEventHeader is available
# Warning in <TClass::Init>: no dictionary for class R3BNeulandHit is available

# %%
file_1000MeV_0MeV=TFile(root_file_folder_path+"all_particles_above_0MeV_1000MeV_n1.root","read")
hist_hE_1000MeV_0MeV=file_1000MeV_0MeV.GetDirectory("HistMonitor").Get("hE")

file_1000MeV_1MeV=TFile(root_file_folder_path+"all_particles_above_1MeV_1000MeV_n1.root","read")
hist_hE_1000MeV_1MeV=file_1000MeV_1MeV.GetDirectory("HistMonitor").Get("hE")

file_1000MeV_2MeV=TFile(root_file_folder_path+"all_particles_above_2MeV_1000MeV_n1.root","read")
hist_hE_1000MeV_2MeV=file_1000MeV_2MeV.GetDirectory("HistMonitor").Get("hE")

file_1000MeV_5MeV=TFile(root_file_folder_path+"all_particles_above_5MeV_1000MeV_n1.root","read")
hist_hE_1000MeV_5MeV=file_1000MeV_5MeV.GetDirectory("HistMonitor").Get("hE")

# %%
file_1500MeV_0MeV=TFile(root_file_folder_path+"all_particles_above_0MeV_1500MeV_n1.root","read")
hist_hE_1500MeV_0MeV=file_1500MeV_0MeV.GetDirectory("HistMonitor").Get("hE")

file_1500MeV_1MeV=TFile(root_file_folder_path+"all_particles_above_1MeV_1500MeV_n1.root","read")
hist_hE_1500MeV_1MeV=file_1500MeV_1MeV.GetDirectory("HistMonitor").Get("hE")

file_1500MeV_2MeV=TFile(root_file_folder_path+"all_particles_above_2MeV_1500MeV_n1.root","read")
hist_hE_1500MeV_2MeV=file_1500MeV_2MeV.GetDirectory("HistMonitor").Get("hE")

file_1500MeV_5MeV=TFile(root_file_folder_path+"all_particles_above_5MeV_1500MeV_n1.root","read")
hist_hE_1500MeV_5MeV=file_1500MeV_5MeV.GetDirectory("HistMonitor").Get("hE")

# %%
#We want to scale the histograms so they all have a value of 1000 at the main peak of the data.

#set a2MeVordingly to cut out the first big peak in the data a2MeVording to bin number
lower_peak_bin=46

#set the value the peaks should be normalised to
normalized_peak_height=1000

# %%
hist_hE_500MeV_0MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_500MeV_0MeV.GetNbinsX())
scaled_hist_hE_500MeV_0MeV=normalized_peak_height/hist_hE_500MeV_0MeV.GetBinContent(hist_hE_500MeV_0MeV.GetMaximumBin())*hist_hE_500MeV_0MeV

hist_hE_500MeV_1MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_500MeV_1MeV.GetNbinsX())
scaled_hist_hE_500MeV_1MeV=normalized_peak_height/hist_hE_500MeV_1MeV.GetBinContent(hist_hE_500MeV_1MeV.GetMaximumBin())*hist_hE_500MeV_1MeV

hist_hE_500MeV_2MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_500MeV_2MeV.GetNbinsX())
scaled_hist_hE_500MeV_2MeV=normalized_peak_height/hist_hE_500MeV_2MeV.GetBinContent(hist_hE_500MeV_2MeV.GetMaximumBin())*hist_hE_500MeV_2MeV

hist_hE_500MeV_5MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_500MeV_5MeV.GetNbinsX())
scaled_hist_hE_500MeV_5MeV=normalized_peak_height/hist_hE_500MeV_5MeV.GetBinContent(hist_hE_500MeV_5MeV.GetMaximumBin())*hist_hE_500MeV_5MeV

# %%
hist_hE_1000MeV_0MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000MeV_0MeV.GetNbinsX())
scaled_hist_hE_1000MeV_0MeV=normalized_peak_height/hist_hE_1000MeV_0MeV.GetBinContent(hist_hE_1000MeV_0MeV.GetMaximumBin())*hist_hE_1000MeV_0MeV

hist_hE_1000MeV_1MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000MeV_1MeV.GetNbinsX())
scaled_hist_hE_1000MeV_1MeV=normalized_peak_height/hist_hE_1000MeV_1MeV.GetBinContent(hist_hE_1000MeV_1MeV.GetMaximumBin())*hist_hE_1000MeV_1MeV

hist_hE_1000MeV_2MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000MeV_2MeV.GetNbinsX())
scaled_hist_hE_1000MeV_2MeV=normalized_peak_height/hist_hE_1000MeV_2MeV.GetBinContent(hist_hE_1000MeV_2MeV.GetMaximumBin())*hist_hE_1000MeV_2MeV

hist_hE_1000MeV_5MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1000MeV_5MeV.GetNbinsX())
scaled_hist_hE_1000MeV_5MeV=normalized_peak_height/hist_hE_1000MeV_5MeV.GetBinContent(hist_hE_1000MeV_5MeV.GetMaximumBin())*hist_hE_1000MeV_5MeV

# %%
hist_hE_1500MeV_0MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1500MeV_0MeV.GetNbinsX())
scaled_hist_hE_1500MeV_0MeV=normalized_peak_height/hist_hE_1500MeV_0MeV.GetBinContent(hist_hE_1500MeV_0MeV.GetMaximumBin())*hist_hE_1500MeV_0MeV

hist_hE_1500MeV_1MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1500MeV_1MeV.GetNbinsX())
scaled_hist_hE_1500MeV_1MeV=normalized_peak_height/hist_hE_1500MeV_1MeV.GetBinContent(hist_hE_1500MeV_1MeV.GetMaximumBin())*hist_hE_1500MeV_1MeV

hist_hE_1500MeV_2MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1500MeV_2MeV.GetNbinsX())
scaled_hist_hE_1500MeV_2MeV=normalized_peak_height/hist_hE_1500MeV_2MeV.GetBinContent(hist_hE_1500MeV_2MeV.GetMaximumBin())*hist_hE_1500MeV_2MeV

hist_hE_1500MeV_5MeV.GetXaxis().SetRange(lower_peak_bin,hist_hE_1500MeV_5MeV.GetNbinsX())
scaled_hist_hE_1500MeV_5MeV=normalized_peak_height/hist_hE_1500MeV_5MeV.GetBinContent(hist_hE_1500MeV_5MeV.GetMaximumBin())*hist_hE_1500MeV_5MeV

# %%
# %jsroot on
canvas=TCanvas("hE","Hit Energy",0,0,2100,700)
canvas.Divide(3,1)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: hE

# %%
canvas.cd(1)
scaled_hist_hE_500MeV_title="500MeV"
legend_500MeV=TLegend(0.6,0.7,0.9,0.9)
legend_500MeV.SetHeader("Hit Energies","C")
hist_500MeV_global_max_list=[scaled_hist_hE_500MeV_0MeV.GetBinContent(scaled_hist_hE_500MeV_0MeV.GetMaximumBin()),
                         scaled_hist_hE_500MeV_1MeV.GetBinContent(scaled_hist_hE_500MeV_1MeV.GetMaximumBin()),
                         scaled_hist_hE_500MeV_2MeV.GetBinContent(scaled_hist_hE_500MeV_2MeV.GetMaximumBin()),
                         scaled_hist_hE_500MeV_2MeV.GetBinContent(scaled_hist_hE_500MeV_5MeV.GetMaximumBin())]

scaled_hist_hE_500MeV_0MeV.SetTitle(scaled_hist_hE_500MeV_title)
scaled_hist_hE_500MeV_0MeV.SetLineColor(4)
scaled_hist_hE_500MeV_0MeV.Draw("same hist")
scaled_hist_hE_500MeV_0MeV.SetStats(0)
legend_500MeV.AddEntry(scaled_hist_hE_500MeV_0MeV,"0MeV")
scaled_hist_hE_500MeV_0MeV.GetXaxis().SetRange(0,scaled_hist_hE_500MeV_0MeV.GetNbinsX())
scaled_hist_hE_500MeV_0MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_500MeV_global_max_list)/100)*100+100)

scaled_hist_hE_500MeV_1MeV.SetTitle(scaled_hist_hE_500MeV_title)
scaled_hist_hE_500MeV_1MeV.SetLineColor(2)
scaled_hist_hE_500MeV_1MeV.Draw("same hist")
scaled_hist_hE_500MeV_1MeV.SetStats(0)
legend_500MeV.AddEntry(scaled_hist_hE_500MeV_1MeV,"1MeV")
scaled_hist_hE_500MeV_1MeV.GetXaxis().SetRange(0,scaled_hist_hE_500MeV_1MeV.GetNbinsX())
scaled_hist_hE_500MeV_1MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_500MeV_global_max_list)/100)*100+100)

scaled_hist_hE_500MeV_2MeV.SetTitle(scaled_hist_hE_500MeV_title)
scaled_hist_hE_500MeV_2MeV.SetLineColor(6)
scaled_hist_hE_500MeV_2MeV.Draw("same hist")
scaled_hist_hE_500MeV_2MeV.SetStats(0)
legend_500MeV.AddEntry(scaled_hist_hE_500MeV_2MeV,"2MeV")
scaled_hist_hE_500MeV_2MeV.GetXaxis().SetRange(0,scaled_hist_hE_500MeV_2MeV.GetNbinsX())
scaled_hist_hE_500MeV_2MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_500MeV_global_max_list)/100)*100+100)

scaled_hist_hE_500MeV_5MeV.SetTitle(scaled_hist_hE_500MeV_title)
scaled_hist_hE_500MeV_5MeV.SetLineColor(8)
scaled_hist_hE_500MeV_5MeV.Draw("same hist")
scaled_hist_hE_500MeV_5MeV.SetStats(0)
legend_500MeV.AddEntry(scaled_hist_hE_500MeV_5MeV,"5MeV")
scaled_hist_hE_500MeV_5MeV.GetXaxis().SetRange(0,scaled_hist_hE_500MeV_5MeV.GetNbinsX())
scaled_hist_hE_500MeV_5MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_500MeV_global_max_list)/100)*100+100)

legend_500MeV.Draw()

# %%
canvas.cd(2)
scaled_hist_hE_1000MeV_title="1000MeV"
legend_1000MeV=TLegend(0.6,0.7,0.9,0.9)
legend_1000MeV.SetHeader("Hit Energies","C")
hist_1000MeV_global_max_list=[scaled_hist_hE_1000MeV_0MeV.GetBinContent(scaled_hist_hE_1000MeV_0MeV.GetMaximumBin()),
                         scaled_hist_hE_1000MeV_1MeV.GetBinContent(scaled_hist_hE_1000MeV_1MeV.GetMaximumBin()),
                         scaled_hist_hE_1000MeV_2MeV.GetBinContent(scaled_hist_hE_1000MeV_2MeV.GetMaximumBin()),
                         scaled_hist_hE_1000MeV_2MeV.GetBinContent(scaled_hist_hE_1000MeV_5MeV.GetMaximumBin()),]

scaled_hist_hE_1000MeV_0MeV.SetTitle(scaled_hist_hE_1000MeV_title)
scaled_hist_hE_1000MeV_0MeV.SetLineColor(4)
scaled_hist_hE_1000MeV_0MeV.Draw("same hist")
scaled_hist_hE_1000MeV_0MeV.SetStats(0)
legend_1000MeV.AddEntry(scaled_hist_hE_1000MeV_0MeV,"0MeV")
scaled_hist_hE_1000MeV_0MeV.GetXaxis().SetRange(0,scaled_hist_hE_1000MeV_0MeV.GetNbinsX())
scaled_hist_hE_1000MeV_0MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000MeV_global_max_list)/100)*100+100)

scaled_hist_hE_1000MeV_1MeV.SetTitle(scaled_hist_hE_1000MeV_title)
scaled_hist_hE_1000MeV_1MeV.SetLineColor(2)
scaled_hist_hE_1000MeV_1MeV.Draw("same hist")
scaled_hist_hE_1000MeV_1MeV.SetStats(0)
legend_1000MeV.AddEntry(scaled_hist_hE_1000MeV_1MeV,"1MeV")
scaled_hist_hE_1000MeV_1MeV.GetXaxis().SetRange(0,scaled_hist_hE_1000MeV_1MeV.GetNbinsX())
scaled_hist_hE_1000MeV_1MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000MeV_global_max_list)/100)*100+100)

scaled_hist_hE_1000MeV_2MeV.SetTitle(scaled_hist_hE_1000MeV_title)
scaled_hist_hE_1000MeV_2MeV.SetLineColor(6)
scaled_hist_hE_1000MeV_2MeV.Draw("same hist")
scaled_hist_hE_1000MeV_2MeV.SetStats(0)
legend_1000MeV.AddEntry(scaled_hist_hE_1000MeV_2MeV,"2MeV")
scaled_hist_hE_1000MeV_2MeV.GetXaxis().SetRange(0,scaled_hist_hE_1000MeV_2MeV.GetNbinsX())
scaled_hist_hE_1000MeV_2MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000MeV_global_max_list)/100)*100+100)

scaled_hist_hE_1000MeV_5MeV.SetTitle(scaled_hist_hE_1000MeV_title)
scaled_hist_hE_1000MeV_5MeV.SetLineColor(8)
scaled_hist_hE_1000MeV_5MeV.Draw("same hist")
scaled_hist_hE_1000MeV_5MeV.SetStats(0)
legend_1000MeV.AddEntry(scaled_hist_hE_1000MeV_5MeV,"5MeV")
scaled_hist_hE_1000MeV_5MeV.GetXaxis().SetRange(0,scaled_hist_hE_1000MeV_5MeV.GetNbinsX())
scaled_hist_hE_1000MeV_5MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1000MeV_global_max_list)/100)*100+100)


legend_1000MeV.Draw()

# %%
canvas.cd(3)
scaled_hist_hE_1500MeV_title="1500MeV"
legend_1500MeV=TLegend(0.6,0.7,0.9,0.9)
legend_1500MeV.SetHeader("Hit Energies","C")
hist_1500MeV_global_max_list=[scaled_hist_hE_1500MeV_0MeV.GetBinContent(scaled_hist_hE_1500MeV_0MeV.GetMaximumBin()),
                         scaled_hist_hE_1500MeV_1MeV.GetBinContent(scaled_hist_hE_1500MeV_1MeV.GetMaximumBin()),
                         scaled_hist_hE_1500MeV_2MeV.GetBinContent(scaled_hist_hE_1500MeV_2MeV.GetMaximumBin()),
                         scaled_hist_hE_1500MeV_2MeV.GetBinContent(scaled_hist_hE_1500MeV_5MeV.GetMaximumBin()),]

scaled_hist_hE_1500MeV_0MeV.SetTitle(scaled_hist_hE_1500MeV_title)
scaled_hist_hE_1500MeV_0MeV.SetLineColor(4)
scaled_hist_hE_1500MeV_0MeV.Draw("same hist")
scaled_hist_hE_1500MeV_0MeV.SetStats(0)
legend_1500MeV.AddEntry(scaled_hist_hE_1500MeV_0MeV,"0MeV")
scaled_hist_hE_1500MeV_0MeV.GetXaxis().SetRange(0,scaled_hist_hE_1500MeV_0MeV.GetNbinsX())
scaled_hist_hE_1500MeV_0MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1500MeV_global_max_list)/100)*100+100)

scaled_hist_hE_1500MeV_1MeV.SetTitle(scaled_hist_hE_1500MeV_title)
scaled_hist_hE_1500MeV_1MeV.SetLineColor(2)
scaled_hist_hE_1500MeV_1MeV.Draw("same hist")
scaled_hist_hE_1500MeV_1MeV.SetStats(0)
legend_1500MeV.AddEntry(scaled_hist_hE_1500MeV_1MeV,"1MeV")
scaled_hist_hE_1500MeV_1MeV.GetXaxis().SetRange(0,scaled_hist_hE_1500MeV_1MeV.GetNbinsX())
scaled_hist_hE_1500MeV_1MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1500MeV_global_max_list)/100)*100+100)

scaled_hist_hE_1500MeV_2MeV.SetTitle(scaled_hist_hE_1500MeV_title)
scaled_hist_hE_1500MeV_2MeV.SetLineColor(6)
scaled_hist_hE_1500MeV_2MeV.Draw("same hist")
scaled_hist_hE_1500MeV_2MeV.SetStats(0)
legend_1500MeV.AddEntry(scaled_hist_hE_1500MeV_2MeV,"2MeV")
scaled_hist_hE_1500MeV_2MeV.GetXaxis().SetRange(0,scaled_hist_hE_1500MeV_2MeV.GetNbinsX())
scaled_hist_hE_1500MeV_2MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1500MeV_global_max_list)/100)*100+100)

scaled_hist_hE_1500MeV_5MeV.SetTitle(scaled_hist_hE_1500MeV_title)
scaled_hist_hE_1500MeV_5MeV.SetLineColor(8)
scaled_hist_hE_1500MeV_5MeV.Draw("same hist")
scaled_hist_hE_1500MeV_5MeV.SetStats(0)
legend_1500MeV.AddEntry(scaled_hist_hE_1500MeV_5MeV,"5MeV")
scaled_hist_hE_1500MeV_5MeV.GetXaxis().SetRange(0,scaled_hist_hE_1500MeV_5MeV.GetNbinsX())
scaled_hist_hE_1500MeV_5MeV.GetYaxis().SetRangeUser(0,math.floor(max(hist_1500MeV_global_max_list)/100)*100+100)

legend_1500MeV.Draw()

# %%
canvas.Draw()
canvas.SaveAs("energy_filter_0,1,2,5.png")
# Out:
# Info in <TCanvas::Print>: png file energy_filter_0,1,2,5.png has been created
# <div id="root_plot_1714048963881" style="width: 2100px; height: 700px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1714048963881(Core) {
# ...

# %%
#y-value cut-off factor for fits
fit_selection_scale=0.9
fit_selection_value=normalized_peak_height*fit_selection_scale

# %%
scaled_hist_hE_500MeV_0MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_500MeV_0MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_500MeV_0MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_0MeV.GetNbinsX())),
                         scaled_hist_hE_500MeV_0MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_500MeV_0MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_0MeV.GetNbinsX())))
scaled_hist_hE_500MeV_1MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_500MeV_1MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_500MeV_1MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_1MeV.GetNbinsX())),
                        scaled_hist_hE_500MeV_1MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_500MeV_1MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_1MeV.GetNbinsX())))
scaled_hist_hE_500MeV_2MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_500MeV_2MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_500MeV_2MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_2MeV.GetNbinsX())),
                         scaled_hist_hE_500MeV_2MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_500MeV_2MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_2MeV.GetNbinsX())))
scaled_hist_hE_500MeV_5MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_500MeV_5MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_500MeV_5MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_5MeV.GetNbinsX())),
                        scaled_hist_hE_500MeV_5MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_500MeV_5MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_500MeV_5MeV.GetNbinsX())))

# %%
scaled_hist_hE_1000MeV_0MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_1000MeV_0MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_1000MeV_0MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_0MeV.GetNbinsX())),
                         scaled_hist_hE_1000MeV_0MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_1000MeV_0MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_0MeV.GetNbinsX())))
scaled_hist_hE_1000MeV_1MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_1000MeV_1MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1000MeV_1MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_1MeV.GetNbinsX())),
                        scaled_hist_hE_1000MeV_1MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1000MeV_1MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_1MeV.GetNbinsX())))
scaled_hist_hE_1000MeV_2MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_1000MeV_2MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_1000MeV_2MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_2MeV.GetNbinsX())),
                         scaled_hist_hE_1000MeV_2MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_1000MeV_2MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_2MeV.GetNbinsX())))
scaled_hist_hE_1000MeV_5MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_1000MeV_5MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1000MeV_5MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_5MeV.GetNbinsX())),
                        scaled_hist_hE_1000MeV_5MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1000MeV_5MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1000MeV_5MeV.GetNbinsX())))

# %%
scaled_hist_hE_1500MeV_0MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_1500MeV_0MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_1500MeV_0MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_0MeV.GetNbinsX())),
                         scaled_hist_hE_1500MeV_0MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_1500MeV_0MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_0MeV.GetNbinsX())))
scaled_hist_hE_1500MeV_1MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_1500MeV_1MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1500MeV_1MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_1MeV.GetNbinsX())),
                        scaled_hist_hE_1500MeV_1MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1500MeV_1MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_1MeV.GetNbinsX())))
scaled_hist_hE_1500MeV_2MeV.Fit("gaus","S 0","same",
                         scaled_hist_hE_1500MeV_2MeV.GetXaxis().GetBinLowEdge(
                             scaled_hist_hE_1500MeV_2MeV.FindFirstBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_2MeV.GetNbinsX())),
                         scaled_hist_hE_1500MeV_2MeV.GetXaxis().GetBinUpEdge(
                             scaled_hist_hE_1500MeV_2MeV.FindLastBinAbove(
                                 fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_2MeV.GetNbinsX())))
scaled_hist_hE_1500MeV_5MeV.Fit("gaus","S 0","same",
                        scaled_hist_hE_1500MeV_5MeV.GetXaxis().GetBinLowEdge(
                            scaled_hist_hE_1500MeV_5MeV.FindFirstBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_5MeV.GetNbinsX())),
                        scaled_hist_hE_1500MeV_5MeV.GetXaxis().GetBinUpEdge(
                            scaled_hist_hE_1500MeV_5MeV.FindLastBinAbove(
                                fit_selection_value,1,lower_peak_bin,scaled_hist_hE_1500MeV_5MeV.GetNbinsX())))

# %%
peak_position_hE_500MeV_0MeV=scaled_hist_hE_500MeV_0MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_500MeV_1MeV=scaled_hist_hE_500MeV_1MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_500MeV_2MeV=scaled_hist_hE_500MeV_2MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_500MeV_5MeV=scaled_hist_hE_500MeV_5MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_500MeV=[peak_position_hE_500MeV_0MeV,
                         peak_position_hE_500MeV_1MeV,
                         peak_position_hE_500MeV_2MeV,
                         peak_position_hE_500MeV_5MeV,
                         ]
array_peak_positions_500MeV

# %%
peak_position_hE_1000MeV_0MeV=scaled_hist_hE_1000MeV_0MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1000MeV_1MeV=scaled_hist_hE_1000MeV_1MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1000MeV_2MeV=scaled_hist_hE_1000MeV_2MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1000MeV_5MeV=scaled_hist_hE_1000MeV_5MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_1000MeV=[peak_position_hE_1000MeV_0MeV,
                         peak_position_hE_1000MeV_1MeV,
                         peak_position_hE_1000MeV_2MeV,
                         peak_position_hE_1000MeV_5MeV,
                         ]
array_peak_positions_1000MeV

# %%
peak_position_hE_1500MeV_0MeV=scaled_hist_hE_1500MeV_0MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1500MeV_1MeV=scaled_hist_hE_1500MeV_1MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1500MeV_2MeV=scaled_hist_hE_1500MeV_2MeV.GetFunction("gaus").GetParameter("Mean")
peak_position_hE_1500MeV_5MeV=scaled_hist_hE_1500MeV_5MeV.GetFunction("gaus").GetParameter("Mean")

array_peak_positions_1500MeV=[peak_position_hE_1500MeV_0MeV,
                         peak_position_hE_1500MeV_1MeV,
                         peak_position_hE_1500MeV_2MeV,
                         peak_position_hE_1500MeV_5MeV]
array_peak_positions_1500MeV

# %%
template_root_file=TFile("all_particles_above_template_n1.root","RECREATE")

template_root_file.WriteObject(scaled_hist_hE_0MeV_0MeV,"0MeV_0MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_0MeV_1MeV,"0MeV_1MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_0MeV_2MeV,"0MeV_2MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_0MeV_5MeV,"0MeV_5MeV_HitEnergy_Hist")

template_root_file.WriteObject(scaled_hist_hE_1000MeV_0MeV,"1000MeV_0MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1000MeV_1MeV,"1000MeV_1MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1000MeV_2MeV,"1000MeV_2MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1000MeV_5MeV,"1000MeV_5MeV_HitEnergy_Hist")

template_root_file.WriteObject(scaled_hist_hE_1500MeV_0MeV,"1500MeV_0MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1500MeV_1MeV,"1500MeV_1MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1500MeV_2MeV,"1500MeV_2MeV_HitEnergy_Hist")
template_root_file.WriteObject(scaled_hist_hE_1500MeV_5MeV,"1500MeV_5MeV_HitEnergy_Hist")

template_root_file.Close()
